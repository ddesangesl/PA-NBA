# %%
import pandas as pd

# %%
nb_games = "10"

# %%
data_type = {"gameId": str, "teamId": str, "W_CONFR_D" : int}
df_stat_last_perf = pd.read_csv('../dataset/team_stat_last_'+ nb_games +'.csv', dtype=data_type )
df_stat_last_perf
# Out:
#            gameId      teamId   GAME_DATE         DUEL WL  DIFF_W  NB_WIN_L10  \
# 0      0021300001  1610612754  2013-10-29  IND vs. ORL  W       0         0.0
# 1      0021300001  1610612753  2013-10-29    ORL @ IND  L       0         0.0
# 2      0021300002  1610612748  2013-10-29  MIA vs. CHI  W       0         0.0
# 3      0021300002  1610612741  2013-10-29    CHI @ MIA  L       0         0.0
# 4      0021300003  1610612747  2013-10-29  LAL vs. LAC  W       0         0.0
# ...           ...         ...         ...          ... ..     ...         ...
# 24077  0022301228  1610612758  2023-12-08    SAC @ PHX  W       3         0.6
# 24078  0022301229  1610612749  2023-12-07  MIL vs. IND  L       9         0.8
# 24079  0022301229  1610612754  2023-12-07    IND @ MIL  W       3         0.5
# 24080  0022301230  1610612747  2023-12-07  LAL vs. NOP  W       4         0.7
# 24081  0022301230  1610612740  2023-12-07    NOP @ LAL  L       2         0.6
#
# ...

# %%
df_stat_last_perf['col'] = df_stat_last_perf.groupby('gameId').cumcount() + 1
df_stat_flatten = df_stat_last_perf.pivot_table(index='gameId', columns=df_stat_last_perf.groupby('gameId').cumcount() + 1, values=['teamId', 'GAME_DATE', 'DUEL', 'WL', 'DIFF_W', 'NB_WIN_L'+nb_games,
       'PCT_TIR_REUSSI_L'+nb_games, 'PCT_3PTS_L'+ nb_games, 'PCT_LANCER_FRANC_L'+ nb_games,
       'estimatedOffensiveRating_L'+ nb_games, 'offensiveRating_L'+ nb_games,
       'estimatedDefensiveRating_L'+ nb_games, 'defensiveRating_L'+ nb_games,
       'estimatedNetRating_L'+ nb_games, 'netRating_L'+ nb_games, 'assistPercentage_L'+ nb_games,
       'assistToTurnover_L'+ nb_games, 'assistRatio_L'+ nb_games,
       'estimatedTeamTurnoverPercentage_L'+ nb_games, 'turnoverRatio_L'+ nb_games,
       'effectiveFieldGoalPercentage_L'+ nb_games, 'trueShootingPercentage_L'+ nb_games,
       'estimatedPace_L'+ nb_games, 'pace_L'+ nb_games, 'pacePer40_L'+ nb_games, 'PIE_L'+ nb_games, 'TOTAL_POINTS', 'teamName', 'W_CONFR_D'], aggfunc='first')

df_stat_flatten.columns = [f'col{col[1]}' for col in df_stat_flatten.columns]


df_stat_flatten = df_stat_flatten.reset_index()
df_stat_flatten
# Out:
#            gameId  col1 col2         col1       col2        col1        col2  \
# 0      0021300001     0    0  IND vs. ORL  ORL @ IND  2013-10-29  2013-10-29
# 1      0021300002     0    0  MIA vs. CHI  CHI @ MIA  2013-10-29  2013-10-29
# 2      0021300003     0    0  LAL vs. LAC  LAC @ LAL  2013-10-29  2013-10-29
# 3      0021300004     0    0  CLE vs. BKN  BKN @ CLE  2013-10-30  2013-10-30
# 4      0021300005     0    1  PHI vs. MIA  MIA @ PHI  2013-10-30  2013-10-30
# ...           ...   ...  ...          ...        ...         ...         ...
# 12036  0022301226    -8    4  POR vs. DAL  DAL @ POR  2023-12-08  2023-12-08
# 12037  0022301227    10    4  BOS vs. NYK  NYK @ BOS  2023-12-08  2023-12-08
# 12038  0022301228     3    3  PHX vs. SAC  SAC @ PHX  2023-12-08  2023-12-08
# 12039  0022301229     9    3  MIL vs. IND  IND @ MIL  2023-12-07  2023-12-07
# 12040  0022301230     4    2  LAL vs. NOP  NOP @ LAL  2023-12-07  2023-12-07
#
# ...

# %%
df_stat_flatten.columns = ['gameId', 'H_DIFF_W', 'A_DIFF_W', 'H_DUEL', 'A_DUEL', 'H_GAME_DATE', 'A_GAME_DATE', 'H_NB_WIN_L'+nb_games, 'A_NB_WIN_L'+nb_games, 'H_PCT_3PT_L'+nb_games, 'A_PCT_3PT_L'+nb_games, 'H_PCT_LANCER_FRANC_L'+nb_games, 'A_PCT_LANCER_FRANC_L'+nb_games, 'H_PCT_TIR_REUSSI_L'+nb_games, 'A_PCT_TIR_REUSSI_L'+nb_games, 'H_PIE_L'+nb_games, 'A_PIE_L'+nb_games, 'H_POINTS', 'A_POINTS', 'H_WL', 'A_WL', 'H_W_CONFR_D', 'A_W_CONFR_D', 'H_assistPercentage_L'+nb_games, 'A_assistPercentage_L'+nb_games, 'H_assistRatio_L'+nb_games, 'A_assistRatio_L'+nb_games, 'H_assistToTurnover_L'+nb_games, 'A_assistToTurnover_L'+nb_games, 'H_defensiveRating_L'+nb_games, 'A_defensiveRating_L'+nb_games, 'H_effectiveFieldGoalPercentage_L'+nb_games, 'A_effectiveFieldGoalPercentage_L'+nb_games, 'H_estimatedDefensiveRating_L'+nb_games, 'A_estimatedDefensiveRating_L'+nb_games, 'H_estimatedNetRating_L'+nb_games, 'A_estimatedNetRating_L'+nb_games, 'H_estimatedOffensiveRating_L'+nb_games, 'A_estimatedOffensiveRating_L'+nb_games, 'H_estimatedPace_L'+nb_games, 'A_estimatedPace_L'+nb_games, 'H_estimatedTeamTurnoverPercentage_L'+nb_games, 'A_estimatedTeamTurnoverPercentage_L'+nb_games, 'H_netRating_L'+nb_games, 'A_netRating_L'+nb_games, 'H_offensiveRating_L'+nb_games, 'A_offensiveRating_L'+nb_games, 'H_pacePer40_L'+nb_games, 'A_pacePer40_L'+nb_games, 'H_pace_L'+nb_games, 'A_pace_L'+nb_games, 'H_teamId', 'A_teamId', 'H_teamName', 'A_teamName', 'H_trueShootingPercentage_L'+nb_games, 'A_trueShootingPercentage_L'+nb_games, 'H_turnoverRatio_L'+nb_games, 'A_turnoverRatio_L'+nb_games]
df_stat_flatten
# Out:
#            gameId  H_DIFF_W  A_DIFF_W       H_DUEL     A_DUEL H_GAME_DATE  \
# 0      0021300001         0         0  IND vs. ORL  ORL @ IND  2013-10-29
# 1      0021300002         0         0  MIA vs. CHI  CHI @ MIA  2013-10-29
# 2      0021300003         0         0  LAL vs. LAC  LAC @ LAL  2013-10-29
# 3      0021300004         0         0  CLE vs. BKN  BKN @ CLE  2013-10-30
# 4      0021300005         0         1  PHI vs. MIA  MIA @ PHI  2013-10-30
# ...           ...       ...       ...          ...        ...         ...
# 12036  0022301226        -8         4  POR vs. DAL  DAL @ POR  2023-12-08
# 12037  0022301227        10         4  BOS vs. NYK  NYK @ BOS  2023-12-08
# 12038  0022301228         3         3  PHX vs. SAC  SAC @ PHX  2023-12-08
# 12039  0022301229         9         3  MIL vs. IND  IND @ MIL  2023-12-07
# 12040  0022301230         4         2  LAL vs. NOP  NOP @ LAL  2023-12-07
#
#       A_GAME_DATE  H_NB_WIN_L10  A_NB_WIN_L10  H_PCT_3PT_L10  ...  H_pace_L10  \
# ...

# %%
df_stat_flatten = df_stat_flatten.drop('A_DUEL', axis=1)
df_stat_flatten = df_stat_flatten.drop('A_GAME_DATE', axis=1)
df_stat_flatten = df_stat_flatten.drop('A_WL', axis=1)
df_stat_flatten = df_stat_flatten.rename(columns={'H_DUEL': 'DUEL', 'H_GAME_DATE': 'GAME_DATE', 'H_WL': 'HOME_WON'})
df_stat_flatten['HOME_WON'] = df_stat_flatten['HOME_WON'].replace('W', 1)
df_stat_flatten['HOME_WON'] = df_stat_flatten['HOME_WON'].replace('L', 0)
df_stat_flatten
# Out:
#            gameId  H_DIFF_W  A_DIFF_W         DUEL   GAME_DATE  H_NB_WIN_L10  \
# 0      0021300001         0         0  IND vs. ORL  2013-10-29           0.0
# 1      0021300002         0         0  MIA vs. CHI  2013-10-29           0.0
# 2      0021300003         0         0  LAL vs. LAC  2013-10-29           0.0
# 3      0021300004         0         0  CLE vs. BKN  2013-10-30           0.0
# 4      0021300005         0         1  PHI vs. MIA  2013-10-30           0.0
# ...           ...       ...       ...          ...         ...           ...
# 12036  0022301226        -8         4  POR vs. DAL  2023-12-08           0.3
# 12037  0022301227        10         4  BOS vs. NYK  2023-12-08           0.7
# 12038  0022301228         3         3  PHX vs. SAC  2023-12-08           0.7
# 12039  0022301229         9         3  MIL vs. IND  2023-12-07           0.8
# 12040  0022301230         4         2  LAL vs. NOP  2023-12-07           0.7
#
# ...

# %%
nba_elo = pd.read_csv('../dataset/nba_elo.csv', dtype=data_type )

# %%
nba_elo_copy= nba_elo.copy()
nba_elo_copy
# Out:
#               date  season  neutral playoff team1 team2     elo1_pre  \
# 0       1946-11-01    1947        0     NaN   TRH   NYK  1300.000000
# 1       1946-11-01    1947        0     NaN   NYK   TRH  1300.000000
# 2       1946-11-02    1947        0     NaN   PRO   BOS  1300.000000
# 3       1946-11-02    1947        0     NaN   STB   PIT  1300.000000
# 4       1946-11-02    1947        0     NaN   CHS   NYK  1300.000000
# ...            ...     ...      ...     ...   ...   ...          ...
# 148933  2024-03-30    2024        0     NaN   MEM   ORL  1325.023208
# 148934  2024-03-30    2024        0     NaN   MIL   ATL  1586.179279
# 148935  2024-03-30    2024        0     NaN   NOP   BOS  1635.324867
# 148936  2024-03-30    2024        0     NaN   ORL   MEM  1523.156879
# 148937  2024-03-30    2024        0     NaN   ATL   MIL  1493.120229
#
#            elo2_pre  elo_prob1  elo_prob2    elo1_post    elo2_post  score1  \
# ...

# %%
columns_list = nba_elo_copy.columns.tolist()

# %%
columns_to_drop = ['season',  'neutral', 'playoff', 'team2', 'elo1_post', 'elo2_post', 'score1', 'score2', 'is_home']  # Liste des noms des colonnes à supprimer
nba_elo_copy_drop= nba_elo_copy.drop(columns=columns_to_drop)

# %%
nba_elo_copy_drop
# Out:
#               date team1     elo1_pre     elo2_pre  elo_prob1  elo_prob2
# 0       1946-11-01   TRH  1300.000000  1300.000000   0.640065   0.359935
# 1       1946-11-01   NYK  1300.000000  1300.000000   0.359935   0.640065
# 2       1946-11-02   PRO  1300.000000  1300.000000   0.640065   0.359935
# 3       1946-11-02   STB  1300.000000  1300.000000   0.640065   0.359935
# 4       1946-11-02   CHS  1300.000000  1306.723300   0.631101   0.368899
# ...            ...   ...          ...          ...        ...        ...
# 148933  2024-03-30   MEM  1325.023208  1523.156879   0.152362   0.847638
# 148934  2024-03-30   MIL  1586.179279  1493.120229   0.490012   0.509988
# 148935  2024-03-30   NOP  1635.324867  1758.207851   0.467116   0.532884
# 148936  2024-03-30   ORL  1523.156879  1325.023208   0.847638   0.152362
# 148937  2024-03-30   ATL  1493.120229  1586.179279   0.509988   0.490012
#
# [148938 rows x 6 columns]

# %%
nba_elo_copy_drop['team1'] = nba_elo_copy_drop['team1'].replace({'PHO': 'PHX', 'BRK': 'BKN', 'CHO': 'CHA'})

# %%
df_stat_flatten['team1'] = df_stat_flatten['DUEL'].str.split(' vs. ').str[0]
df_stat_flatten
# Out:
#            gameId  H_DIFF_W  A_DIFF_W         DUEL   GAME_DATE  H_NB_WIN_L10  \
# 0      0021300001         0         0  IND vs. ORL  2013-10-29           0.0
# 1      0021300002         0         0  MIA vs. CHI  2013-10-29           0.0
# 2      0021300003         0         0  LAL vs. LAC  2013-10-29           0.0
# 3      0021300004         0         0  CLE vs. BKN  2013-10-30           0.0
# 4      0021300005         0         1  PHI vs. MIA  2013-10-30           0.0
# ...           ...       ...       ...          ...         ...           ...
# 12036  0022301226        -8         4  POR vs. DAL  2023-12-08           0.3
# 12037  0022301227        10         4  BOS vs. NYK  2023-12-08           0.7
# 12038  0022301228         3         3  PHX vs. SAC  2023-12-08           0.7
# 12039  0022301229         9         3  MIL vs. IND  2023-12-07           0.8
# 12040  0022301230         4         2  LAL vs. NOP  2023-12-07           0.7
#
# ...

# %%
new_column_names = {'date':'GAME_DATE' }
nba_elo_copy_drop_rename= nba_elo_copy_drop.rename(columns=new_column_names)
nba_elo_copy_drop_rename
# Out:
#          GAME_DATE team1     elo1_pre     elo2_pre  elo_prob1  elo_prob2
# 0       1946-11-01   TRH  1300.000000  1300.000000   0.640065   0.359935
# 1       1946-11-01   NYK  1300.000000  1300.000000   0.359935   0.640065
# 2       1946-11-02   PRO  1300.000000  1300.000000   0.640065   0.359935
# 3       1946-11-02   STB  1300.000000  1300.000000   0.640065   0.359935
# 4       1946-11-02   CHS  1300.000000  1306.723300   0.631101   0.368899
# ...            ...   ...          ...          ...        ...        ...
# 148933  2024-03-30   MEM  1325.023208  1523.156879   0.152362   0.847638
# 148934  2024-03-30   MIL  1586.179279  1493.120229   0.490012   0.509988
# 148935  2024-03-30   NOP  1635.324867  1758.207851   0.467116   0.532884
# 148936  2024-03-30   ORL  1523.156879  1325.023208   0.847638   0.152362
# 148937  2024-03-30   ATL  1493.120229  1586.179279   0.509988   0.490012
#
# [148938 rows x 6 columns]

# %%
df_stat_flatten = pd.merge(df_stat_flatten, nba_elo_copy_drop_rename, on=['GAME_DATE', 'team1'])
df_stat_flatten
# Out:
#            gameId  H_DIFF_W  A_DIFF_W         DUEL   GAME_DATE  H_NB_WIN_L10  \
# 0      0021300001         0         0  IND vs. ORL  2013-10-29           0.0
# 1      0021300002         0         0  MIA vs. CHI  2013-10-29           0.0
# 2      0021300003         0         0  LAL vs. LAC  2013-10-29           0.0
# 3      0021300004         0         0  CLE vs. BKN  2013-10-30           0.0
# 4      0021300005         0         1  PHI vs. MIA  2013-10-30           0.0
# ...           ...       ...       ...          ...         ...           ...
# 11911  0022301226        -8         4  POR vs. DAL  2023-12-08           0.3
# 11912  0022301227        10         4  BOS vs. NYK  2023-12-08           0.7
# 11913  0022301228         3         3  PHX vs. SAC  2023-12-08           0.7
# 11914  0022301229         9         3  MIL vs. IND  2023-12-07           0.8
# 11915  0022301230         4         2  LAL vs. NOP  2023-12-07           0.7
#
# ...

# %%
new_column_names = {'elo1_pre':'H_ELO' , 'elo2_pre': 'A_ELO', 'elo_prob1':'H_ELO_PROB', 'elo_prob2':'A_ELO_PROB'}
df_stat_flatten= df_stat_flatten.rename(columns=new_column_names)
df_stat_flatten
# Out:
#            gameId  H_DIFF_W  A_DIFF_W         DUEL   GAME_DATE  H_NB_WIN_L10  \
# 0      0021300001         0         0  IND vs. ORL  2013-10-29           0.0
# 1      0021300002         0         0  MIA vs. CHI  2013-10-29           0.0
# 2      0021300003         0         0  LAL vs. LAC  2013-10-29           0.0
# 3      0021300004         0         0  CLE vs. BKN  2013-10-30           0.0
# 4      0021300005         0         1  PHI vs. MIA  2013-10-30           0.0
# ...           ...       ...       ...          ...         ...           ...
# 11911  0022301226        -8         4  POR vs. DAL  2023-12-08           0.3
# 11912  0022301227        10         4  BOS vs. NYK  2023-12-08           0.7
# 11913  0022301228         3         3  PHX vs. SAC  2023-12-08           0.7
# 11914  0022301229         9         3  MIL vs. IND  2023-12-07           0.8
# 11915  0022301230         4         2  LAL vs. NOP  2023-12-07           0.7
#
# ...

# %%
new_order = ['gameId', 'DUEL','GAME_DATE','H_POINTS', 'A_POINTS','H_teamName', 'A_teamName', 'HOME_WON', 'H_DIFF_W', 'A_DIFF_W', 'H_ELO','A_ELO','H_ELO_PROB','A_ELO_PROB', 'H_W_CONFR_D', 'A_W_CONFR_D', 'H_NB_WIN_L'+nb_games,'A_NB_WIN_L'+nb_games, 'H_PCT_3PT_L'+ nb_games,
       'A_PCT_3PT_L'+ nb_games, 'H_PCT_LANCER_FRANC_L'+ nb_games, 'A_PCT_LANCER_FRANC_L'+ nb_games,
       'H_PCT_TIR_REUSSI_L'+ nb_games, 'A_PCT_TIR_REUSSI_L'+ nb_games, 'H_PIE_L'+ nb_games,
       'A_PIE_L'+ nb_games,  'H_assistPercentage_L'+ nb_games,
       'A_assistPercentage_L'+ nb_games, 'H_assistRatio_L'+ nb_games, 'A_assistRatio_L'+ nb_games,
       'H_assistToTurnover_L'+ nb_games, 'A_assistToTurnover_L'+ nb_games,
       'H_defensiveRating_L'+ nb_games, 'A_defensiveRating_L'+ nb_games,
       'H_effectiveFieldGoalPercentage_L'+ nb_games,
       'A_effectiveFieldGoalPercentage_L'+ nb_games, 'H_estimatedDefensiveRating_L'+ nb_games,
       'A_estimatedDefensiveRating_L'+ nb_games, 'H_estimatedNetRating_L'+ nb_games,
       'A_estimatedNetRating_L'+ nb_games, 'H_estimatedOffensiveRating_L'+ nb_games,
       'A_estimatedOffensiveRating_L'+ nb_games, 'H_estimatedPace_L'+ nb_games,
       'A_estimatedPace_L'+ nb_games, 'H_estimatedTeamTurnoverPercentage_L'+ nb_games,
       'A_estimatedTeamTurnoverPercentage_L'+ nb_games, 'H_netRating_L'+ nb_games,
       'A_netRating_L'+ nb_games, 'H_offensiveRating_L'+ nb_games, 'A_offensiveRating_L'+ nb_games,
       'H_pacePer40_L'+ nb_games, 'A_pacePer40_L'+ nb_games, 'H_pace_L'+ nb_games, 'A_pace_L'+ nb_games,
       'H_teamId', 'A_teamId', 'H_trueShootingPercentage_L'+ nb_games,
       'A_trueShootingPercentage_L'+ nb_games, 'H_turnoverRatio_L'+ nb_games,
       'A_turnoverRatio_L'+ nb_games, 'team1']

# Réorganiser les colonnes
df_stat_flatten = df_stat_flatten.reindex(columns=new_order)
df_stat_flatten = df_stat_flatten.drop(columns=['team1'])
df_stat_flatten
# Out:
#            gameId         DUEL   GAME_DATE  H_POINTS  A_POINTS  \
# 0      0021300001  IND vs. ORL  2013-10-29        97        87
# 1      0021300002  MIA vs. CHI  2013-10-29       107        95
# 2      0021300003  LAL vs. LAC  2013-10-29       116       103
# 3      0021300004  CLE vs. BKN  2013-10-30        98        94
# 4      0021300005  PHI vs. MIA  2013-10-30       114       110
# ...           ...          ...         ...       ...       ...
# 11911  0022301226  POR vs. DAL  2023-12-08       112       125
# 11912  0022301227  BOS vs. NYK  2023-12-08       133       123
# 11913  0022301228  PHX vs. SAC  2023-12-08       106       114
# 11914  0022301229  MIL vs. IND  2023-12-07       119       128
# 11915  0022301230  LAL vs. NOP  2023-12-07       133        89
#
#                    H_teamName            A_teamName  HOME_WON  H_DIFF_W  \
# 0              Indiana Pacers         Orlando Magic         1         0
# ...

# %%
df_stat_flatten = df_stat_flatten.dropna()
df_stat_flatten
# Out:
#            gameId         DUEL   GAME_DATE  H_POINTS  A_POINTS  \
# 17     0021300018  CHI vs. NYK  2013-10-31        82        81
# 18     0021300019  LAC vs. GSW  2013-10-31       126       115
# 19     0021300020  CHA vs. CLE  2013-11-01        90        84
# 20     0021300021  ORL vs. NOP  2013-11-01       110        90
# 21     0021300022  WAS vs. PHI  2013-11-01       102       109
# ...           ...          ...         ...       ...       ...
# 11911  0022301226  POR vs. DAL  2023-12-08       112       125
# 11912  0022301227  BOS vs. NYK  2023-12-08       133       123
# 11913  0022301228  PHX vs. SAC  2023-12-08       106       114
# 11914  0022301229  MIL vs. IND  2023-12-07       119       128
# 11915  0022301230  LAL vs. NOP  2023-12-07       133        89
#
#                    H_teamName             A_teamName  HOME_WON  H_DIFF_W  \
# 17              Chicago Bulls        New York Knicks         1        -1
# ...

# %%
df_stat_flatten.columns
# Out:
# Index(['gameId', 'DUEL', 'GAME_DATE', 'H_POINTS', 'A_POINTS', 'H_teamName',
#        'A_teamName', 'HOME_WON', 'H_DIFF_W', 'A_DIFF_W', 'H_ELO', 'A_ELO',
#        'H_ELO_PROB', 'A_ELO_PROB', 'H_W_CONFR_D', 'A_W_CONFR_D',
#        'H_NB_WIN_L10', 'A_NB_WIN_L10', 'H_PCT_3PT_L10', 'A_PCT_3PT_L10',
#        'H_PCT_LANCER_FRANC_L10', 'A_PCT_LANCER_FRANC_L10',
#        'H_PCT_TIR_REUSSI_L10', 'A_PCT_TIR_REUSSI_L10', 'H_PIE_L10',
#        'A_PIE_L10', 'H_assistPercentage_L10', 'A_assistPercentage_L10',
#        'H_assistRatio_L10', 'A_assistRatio_L10', 'H_assistToTurnover_L10',
#        'A_assistToTurnover_L10', 'H_defensiveRating_L10',
#        'A_defensiveRating_L10', 'H_effectiveFieldGoalPercentage_L10',
#        'A_effectiveFieldGoalPercentage_L10', 'H_estimatedDefensiveRating_L10',
#        'A_estimatedDefensiveRating_L10', 'H_estimatedNetRating_L10',
#        'A_estimatedNetRating_L10', 'H_estimatedOffensiveRating_L10',
#        'A_estimatedOffensiveRating_L10', 'H_estimatedPace_L10',
# ...

# %%
df_stat_flatten = df_stat_flatten.drop(columns=['DUEL'])
colonne_a_supprimer = df_stat_flatten.columns[7:].tolist()
# Boucle sur chaque paire de colonnes pour calculer la différence
i = 0 
for colonne in colonne_a_supprimer:
    
    
    if colonne != "H_teamId" and colonne != "A_teamId":
           # Extraire le préfixe de la colonne ('H_' ou 'A_')
           prefixe = colonne[0:2]
           # Extraire le nom de la colonne sans le préfixe
           nom_colonne = colonne[2:]
           # Créer une nouvelle colonne pour stocker la différence
           df_stat_flatten[f'{nom_colonne}'] = df_stat_flatten.apply(lambda row: row[f'H_{nom_colonne}'] - row[f'A_{nom_colonne}'], axis=1)
    i = i +1    
colonne_a_supprimer.remove("A_teamId")
colonne_a_supprimer.remove("H_teamId")
df_stat_flatten = df_stat_flatten.drop(columns=colonne_a_supprimer)
       
df_stat_flatten
# Out:
#            gameId   GAME_DATE  H_POINTS  A_POINTS              H_teamName  \
# 17     0021300018  2013-10-31        82        81           Chicago Bulls
# 18     0021300019  2013-10-31       126       115    Los Angeles Clippers
# 19     0021300020  2013-11-01        90        84       Charlotte Bobcats
# 20     0021300021  2013-11-01       110        90           Orlando Magic
# 21     0021300022  2013-11-01       102       109      Washington Wizards
# ...           ...         ...       ...       ...                     ...
# 11911  0022301226  2023-12-08       112       125  Portland Trail Blazers
# 11912  0022301227  2023-12-08       133       123          Boston Celtics
# 11913  0022301228  2023-12-08       106       114            Phoenix Suns
# 11914  0022301229  2023-12-07       119       128         Milwaukee Bucks
# 11915  0022301230  2023-12-07       133        89      Los Angeles Lakers
#
#                   A_teamName  HOME_WON    H_teamId    A_teamId  DIFF_W  ...  \
# ...

# %%
df_stat_flatten.to_csv('../dataset/final_dataset.csv', index=False)
