# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
data_type = {"gameId": str, "teamId": str}
df_stat_last_40 = pd.read_csv('../dataset/team_stat_last_40.csv', dtype=data_type )
df_stat_last_40
# Out:
#          gameId      teamId   GAME_DATE         DUEL WL  NB_WIN_L40  \
# 0      21300001  1610612754  2013-10-29  IND vs. ORL  W           0
# 1      21300001  1610612753  2013-10-29    ORL @ IND  L           0
# 2      21300002  1610612748  2013-10-29  MIA vs. CHI  W           0
# 3      21300002  1610612741  2013-10-29    CHI @ MIA  L           0
# 4      21300003  1610612747  2013-10-29  LAL vs. LAC  W           0
# ...         ...         ...         ...          ... ..         ...
# 25943  22301228  1610612758  2023-12-08    SAC @ PHX  W          23
# 25944  22301229  1610612749  2023-12-07  MIL vs. IND  L          28
# 25945  22301229  1610612754  2023-12-07    IND @ MIL  W          20
# 25946  22301230  1610612747  2023-12-07  LAL vs. NOP  W          26
# 25947  22301230  1610612740  2023-12-07    NOP @ LAL  L          23
#
#        PCT_TIR_REUSSI_L40  PCT_3PTS_L40  PCT_LANCER_FRANC_L40  \
# 0                     NaN           NaN                   NaN
# ...

# %%
df_stat_last_40['col'] = df_stat_last_40.groupby('gameId').cumcount() + 1
df_stat_flatten = df_stat_last_40.pivot_table(index='gameId', columns=df_stat_last_40.groupby('gameId').cumcount() + 1, values=['teamId', 'GAME_DATE', 'DUEL', 'WL', 'NB_WIN_L40',
       'PCT_TIR_REUSSI_L40', 'PCT_3PTS_L40', 'PCT_LANCER_FRANC_L40',
       'estimatedOffensiveRating_L40', 'offensiveRating_L40',
       'estimatedDefensiveRating_L40', 'defensiveRating_L40',
       'estimatedNetRating_L40', 'netRating_L40', 'assistPercentage_L40',
       'assistToTurnover_L40', 'assistRatio_L40',
       'estimatedTeamTurnoverPercentage_L40', 'turnoverRatio_L40',
       'effectiveFieldGoalPercentage_L40', 'trueShootingPercentage_L40',
       'estimatedPace_L40', 'pace_L40', 'pacePer40_L40', 'PIE_L40'], aggfunc='first')

df_stat_flatten.columns = [f'col{col[1]}' for col in df_stat_flatten.columns]


df_stat_flatten = df_stat_flatten.reset_index()
#df_stat_flatten

# %%
df_stat_flatten
# Out:
#          gameId         col1       col2        col1        col2  col1  col2  \
# 0      21300001  IND vs. ORL  ORL @ IND  2013-10-29  2013-10-29     0     0
# 1      21300002  MIA vs. CHI  CHI @ MIA  2013-10-29  2013-10-29     0     0
# 2      21300003  LAL vs. LAC  LAC @ LAL  2013-10-29  2013-10-29     0     0
# 3      21300004  CLE vs. BKN  BKN @ CLE  2013-10-30  2013-10-30     0     0
# 4      21300005  PHI vs. MIA  MIA @ PHI  2013-10-30  2013-10-30     0     1
# ...         ...          ...        ...         ...         ...   ...   ...
# 12969  22301226  POR vs. DAL  DAL @ POR  2023-12-08  2023-12-08    10    18
# 12970  22301227  BOS vs. NYK  NYK @ BOS  2023-12-08  2023-12-08    28    24
# 12971  22301228  PHX vs. SAC  SAC @ PHX  2023-12-08  2023-12-08    23    23
# 12972  22301229  MIL vs. IND  IND @ MIL  2023-12-07  2023-12-07    28    20
# 12973  22301230  LAL vs. NOP  NOP @ LAL  2023-12-07  2023-12-07    26    23
#
# ...

# %%
print(len(['DUEL', 'GAME_DATE', 'NB_WIN_L40', 'PCT_3PT_L40', 'PCT_LANCER_FRANC_L40', 'PCT_TIR_REUSSI_L40', 'PIE_L40', 'WL', 'assistPercentage_L40', 'assistRatio_L40', 'assistToTurnover_L40', 'defensiveRating_L40', 'effectiveFieldGoalPercentage_L40', 'estimatedDefensiveRating_L40', 'estimatedNetRating_L40', 'estimatedOffensiveRating_L40', 'estimatedPace_L40', 'estimatedTeamTurnoverPercentage_L40', 'netRating_L40', 'offensiveRating_L40','pacePer40_L40', 'pace_L40','teamId', 'trueShootingPercentage_L40', 'turnoverRatio_L40']))
# Out:
# 25

# %%
df_stat_flatten.columns = ['gameId', 'H_DUEL', 'A_DUEL', 'H_GAME_DATE', 'A_GAME_DATE', 'H_NB_WIN_L40', 'A_NB_WIN_L40', 'H_PCT_3PT_L40', 'A_PCT_3PT_L40', 'H_PCT_LANCER_FRANC_L40', 'A_PCT_LANCER_FRANC_L40', 'H_PCT_TIR_REUSSI_L40', 'A_PCT_TIR_REUSSI_L40', 'H_PIE_L40', 'A_PIE_L40', 'H_WL', 'A_WL', 'H_assistPercentage_L40', 'A_assistPercentage_L40', 'H_assistRatio_L40', 'A_assistRatio_L40', 'H_assistToTurnover_L40', 'A_assistToTurnover_L40', 'H_defensiveRating_L40', 'A_defensiveRating_L40', 'H_effectiveFieldGoalPercentage_L40', 'A_effectiveFieldGoalPercentage_L40', 'H_estimatedDefensiveRating_L40', 'A_estimatedDefensiveRating_L40', 'H_estimatedNetRating_L40', 'A_estimatedNetRating_L40', 'H_estimatedOffensiveRating_L40', 'A_estimatedOffensiveRating_L40', 'H_estimatedPace_L40', 'A_estimatedPace_L40', 'H_estimatedTeamTurnoverPercentage_L40', 'A_estimatedTeamTurnoverPercentage_L40', 'H_netRating_L40', 'A_netRating_L40', 'H_offensiveRating_L40', 'A_offensiveRating_L40', 'H_pacePer40_L40', 'A_pacePer40_L40', 'H_pace_L40', 'A_pace_L40', 'H_teamId', 'A_teamId', 'H_trueShootingPercentage_L40', 'A_trueShootingPercentage_L40', 'H_turnoverRatio_L40', 'A_turnoverRatio_L40']
df_stat_flatten
# Out:
#          gameId       H_DUEL     A_DUEL H_GAME_DATE A_GAME_DATE  H_NB_WIN_L40  \
# 0      21300001  IND vs. ORL  ORL @ IND  2013-10-29  2013-10-29             0
# 1      21300002  MIA vs. CHI  CHI @ MIA  2013-10-29  2013-10-29             0
# 2      21300003  LAL vs. LAC  LAC @ LAL  2013-10-29  2013-10-29             0
# 3      21300004  CLE vs. BKN  BKN @ CLE  2013-10-30  2013-10-30             0
# 4      21300005  PHI vs. MIA  MIA @ PHI  2013-10-30  2013-10-30             0
# ...         ...          ...        ...         ...         ...           ...
# 12969  22301226  POR vs. DAL  DAL @ POR  2023-12-08  2023-12-08            10
# 12970  22301227  BOS vs. NYK  NYK @ BOS  2023-12-08  2023-12-08            28
# 12971  22301228  PHX vs. SAC  SAC @ PHX  2023-12-08  2023-12-08            23
# 12972  22301229  MIL vs. IND  IND @ MIL  2023-12-07  2023-12-07            28
# 12973  22301230  LAL vs. NOP  NOP @ LAL  2023-12-07  2023-12-07            26
#
# ...

# %%
df_stat_flatten = df_stat_flatten.drop('A_DUEL', axis=1)
df_stat_flatten = df_stat_flatten.drop('A_GAME_DATE', axis=1)
df_stat_flatten = df_stat_flatten.drop('A_WL', axis=1)
df_stat_flatten = df_stat_flatten.rename(columns={'H_DUEL': 'DUEL', 'H_GAME_DATE': 'GAME_DATE', 'H_WL': 'HOME_WON'})
df_stat_flatten['HOME_WON'] = df_stat_flatten['HOME_WON'].replace('W', 1)
df_stat_flatten['HOME_WON'] = df_stat_flatten['HOME_WON'].replace('L', 0)
df_stat_flatten
# Out:
#          gameId         DUEL   GAME_DATE  H_NB_WIN_L40  A_NB_WIN_L40  \
# 0      21300001  IND vs. ORL  2013-10-29             0             0
# 1      21300002  MIA vs. CHI  2013-10-29             0             0
# 2      21300003  LAL vs. LAC  2013-10-29             0             0
# 3      21300004  CLE vs. BKN  2013-10-30             0             0
# 4      21300005  PHI vs. MIA  2013-10-30             0             1
# ...         ...          ...         ...           ...           ...
# 12969  22301226  POR vs. DAL  2023-12-08            10            18
# 12970  22301227  BOS vs. NYK  2023-12-08            28            24
# 12971  22301228  PHX vs. SAC  2023-12-08            23            23
# 12972  22301229  MIL vs. IND  2023-12-07            28            20
# 12973  22301230  LAL vs. NOP  2023-12-07            26            23
#
#        H_PCT_3PT_L40  A_PCT_3PT_L40  H_PCT_LANCER_FRANC_L40  \
# 0                NaN            NaN                     NaN
# ...

# %%
df_stat_flatten.to_csv('../dataset/team_stat_flatten_L40.csv', index=False)

# %%
nba_elo = pd.read_csv('../dataset/nba_elo.csv', dtype=data_type )

# %%
nba_elo_copy= nba_elo.copy()
nba_elo_copy
# Out:
#               date  season  neutral playoff team1 team2     elo1_pre  \
# 0       1946-11-01    1947        0     NaN   TRH   NYK  1300.000000
# 1       1946-11-01    1947        0     NaN   NYK   TRH  1300.000000
# 2       1946-11-02    1947        0     NaN   PRO   BOS  1300.000000
# 3       1946-11-02    1947        0     NaN   STB   PIT  1300.000000
# 4       1946-11-02    1947        0     NaN   CHS   NYK  1300.000000
# ...            ...     ...      ...     ...   ...   ...          ...
# 148933  2024-03-30    2024        0     NaN   MEM   ORL  1325.023208
# 148934  2024-03-30    2024        0     NaN   MIL   ATL  1586.179279
# 148935  2024-03-30    2024        0     NaN   NOP   BOS  1635.324867
# 148936  2024-03-30    2024        0     NaN   ORL   MEM  1523.156879
# 148937  2024-03-30    2024        0     NaN   ATL   MIL  1493.120229
#
#            elo2_pre  elo_prob1  elo_prob2    elo1_post    elo2_post  score1  \
# ...

# %%
columns_list = nba_elo_copy.columns.tolist()

print(columns_list)
# Out:
# ['date', 'season', 'neutral', 'playoff', 'team1', 'team2', 'elo1_pre', 'elo2_pre', 'elo_prob1', 'elo_prob2', 'elo1_post', 'elo2_post', 'score1', 'score2', 'is_home']

# %%
columns_to_drop = ['season',  'neutral', 'playoff', 'team2', 'elo_prob1', 'elo_prob2', 'elo1_post', 'elo2_post', 'score1', 'score2', 'is_home']  # Liste des noms des colonnes à supprimer
nba_elo_copy_drop= nba_elo_copy.drop(columns=columns_to_drop)

# %%
nba_elo_copy_drop
# Out:
#               date team1     elo1_pre     elo2_pre
# 0       1946-11-01   TRH  1300.000000  1300.000000
# 1       1946-11-01   NYK  1300.000000  1300.000000
# 2       1946-11-02   PRO  1300.000000  1300.000000
# 3       1946-11-02   STB  1300.000000  1300.000000
# 4       1946-11-02   CHS  1300.000000  1306.723300
# ...            ...   ...          ...          ...
# 148933  2024-03-30   MEM  1325.023208  1523.156879
# 148934  2024-03-30   MIL  1586.179279  1493.120229
# 148935  2024-03-30   NOP  1635.324867  1758.207851
# 148936  2024-03-30   ORL  1523.156879  1325.023208
# 148937  2024-03-30   ATL  1493.120229  1586.179279
#
# [148938 rows x 4 columns]

# %%
nba_elo_copy_drop['team1'] = nba_elo_copy_drop['team1'].replace({'PHO': 'PHX', 'BRK': 'BKN', 'CHO': 'CHA'})

# %%
df_stat_flatten['team1'] = df_stat_flatten['DUEL'].str.split(' vs. ').str[0]

# %%
df_stat_flatten
# Out:
#          gameId         DUEL   GAME_DATE  H_NB_WIN_L40  A_NB_WIN_L40  \
# 0      21300001  IND vs. ORL  2013-10-29             0             0
# 1      21300002  MIA vs. CHI  2013-10-29             0             0
# 2      21300003  LAL vs. LAC  2013-10-29             0             0
# 3      21300004  CLE vs. BKN  2013-10-30             0             0
# 4      21300005  PHI vs. MIA  2013-10-30             0             1
# ...         ...          ...         ...           ...           ...
# 12969  22301226  POR vs. DAL  2023-12-08            10            18
# 12970  22301227  BOS vs. NYK  2023-12-08            28            24
# 12971  22301228  PHX vs. SAC  2023-12-08            23            23
# 12972  22301229  MIL vs. IND  2023-12-07            28            20
# 12973  22301230  LAL vs. NOP  2023-12-07            26            23
#
#        H_PCT_3PT_L40  A_PCT_3PT_L40  H_PCT_LANCER_FRANC_L40  \
# 0                NaN            NaN                     NaN
# ...

# %%
new_column_names = {'date':'GAME_DATE' }
nba_elo_copy_drop_rename= nba_elo_copy_drop.rename(columns=new_column_names)
nba_elo_copy_drop_rename
# Out:
#          GAME_DATE team1     elo1_pre     elo2_pre
# 0       1946-11-01   TRH  1300.000000  1300.000000
# 1       1946-11-01   NYK  1300.000000  1300.000000
# 2       1946-11-02   PRO  1300.000000  1300.000000
# 3       1946-11-02   STB  1300.000000  1300.000000
# 4       1946-11-02   CHS  1300.000000  1306.723300
# ...            ...   ...          ...          ...
# 148933  2024-03-30   MEM  1325.023208  1523.156879
# 148934  2024-03-30   MIL  1586.179279  1493.120229
# 148935  2024-03-30   NOP  1635.324867  1758.207851
# 148936  2024-03-30   ORL  1523.156879  1325.023208
# 148937  2024-03-30   ATL  1493.120229  1586.179279
#
# [148938 rows x 4 columns]

# %%
result = pd.merge(df_stat_flatten, nba_elo_copy_drop_rename, on=['GAME_DATE', 'team1'])

# %%
result
# Out:
#          gameId         DUEL   GAME_DATE  H_NB_WIN_L40  A_NB_WIN_L40  \
# 0      21300001  IND vs. ORL  2013-10-29             0             0
# 1      21300002  MIA vs. CHI  2013-10-29             0             0
# 2      21300003  LAL vs. LAC  2013-10-29             0             0
# 3      21300004  CLE vs. BKN  2013-10-30             0             0
# 4      21300005  PHI vs. MIA  2013-10-30             0             1
# ...         ...          ...         ...           ...           ...
# 12969  22301226  POR vs. DAL  2023-12-08            10            18
# 12970  22301227  BOS vs. NYK  2023-12-08            28            24
# 12971  22301228  PHX vs. SAC  2023-12-08            23            23
# 12972  22301229  MIL vs. IND  2023-12-07            28            20
# 12973  22301230  LAL vs. NOP  2023-12-07            26            23
#
#        H_PCT_3PT_L40  A_PCT_3PT_L40  H_PCT_LANCER_FRANC_L40  \
# 0                NaN            NaN                     NaN
# ...

# %%
new_column_names = {'elo1_pre':'A_ELO' , 'elo2_pre': 'H_ELO'}
result= result.rename(columns=new_column_names)
result
# Out:
#          gameId         DUEL   GAME_DATE  H_NB_WIN_L40  A_NB_WIN_L40  \
# 0      21300001  IND vs. ORL  2013-10-29             0             0
# 1      21300002  MIA vs. CHI  2013-10-29             0             0
# 2      21300003  LAL vs. LAC  2013-10-29             0             0
# 3      21300004  CLE vs. BKN  2013-10-30             0             0
# 4      21300005  PHI vs. MIA  2013-10-30             0             1
# ...         ...          ...         ...           ...           ...
# 12969  22301226  POR vs. DAL  2023-12-08            10            18
# 12970  22301227  BOS vs. NYK  2023-12-08            28            24
# 12971  22301228  PHX vs. SAC  2023-12-08            23            23
# 12972  22301229  MIL vs. IND  2023-12-07            28            20
# 12973  22301230  LAL vs. NOP  2023-12-07            26            23
#
#        H_PCT_3PT_L40  A_PCT_3PT_L40  H_PCT_LANCER_FRANC_L40  \
# 0                NaN            NaN                     NaN
# ...

# %%
new_order = ['gameId', 'DUEL','GAME_DATE','HOME_WON','H_ELO','A_ELO','H_NB_WIN_L40','A_NB_WIN_L40', 'H_PCT_3PT_L40',
       'A_PCT_3PT_L40', 'H_PCT_LANCER_FRANC_L40', 'A_PCT_LANCER_FRANC_L40',
       'H_PCT_TIR_REUSSI_L40', 'A_PCT_TIR_REUSSI_L40', 'H_PIE_L40',
       'A_PIE_L40',  'H_assistPercentage_L40',
       'A_assistPercentage_L40', 'H_assistRatio_L40', 'A_assistRatio_L40',
       'H_assistToTurnover_L40', 'A_assistToTurnover_L40',
       'H_defensiveRating_L40', 'A_defensiveRating_L40',
       'H_effectiveFieldGoalPercentage_L40',
       'A_effectiveFieldGoalPercentage_L40', 'H_estimatedDefensiveRating_L40',
       'A_estimatedDefensiveRating_L40', 'H_estimatedNetRating_L40',
       'A_estimatedNetRating_L40', 'H_estimatedOffensiveRating_L40',
       'A_estimatedOffensiveRating_L40', 'H_estimatedPace_L40',
       'A_estimatedPace_L40', 'H_estimatedTeamTurnoverPercentage_L40',
       'A_estimatedTeamTurnoverPercentage_L40', 'H_netRating_L40',
       'A_netRating_L40', 'H_offensiveRating_L40', 'A_offensiveRating_L40',
       'H_pacePer40_L40', 'A_pacePer40_L40', 'H_pace_L40', 'A_pace_L40',
       'H_teamId', 'A_teamId', 'H_trueShootingPercentage_L40',
       'A_trueShootingPercentage_L40', 'H_turnoverRatio_L40',
       'A_turnoverRatio_L40', 'team1']

# Réorganiser les colonnes
result = result.reindex(columns=new_order)

# %%
result = result.drop(columns=['team1'])

# %%
result = result.dropna()

# %%
result.to_csv('../dataset/team_stat_flatten_L40.csv', index=False)
result
# Out:
#          gameId         DUEL   GAME_DATE  HOME_WON        H_ELO        A_ELO  \
# 17     21300018  CHI vs. NYK  2013-10-31         1  1582.133300  1516.608800
# 18     21300019  LAC vs. GSW  2013-10-31         1  1574.897700  1575.414200
# 19     21300020  CHA vs. CLE  2013-11-01         1  1377.546500  1349.502100
# 20     21300021  ORL vs. NOP  2013-11-01         1  1422.004600  1309.402000
# 21     21300022  WAS vs. PHI  2013-11-01         0  1469.418000  1452.716800
# ...         ...          ...         ...       ...          ...          ...
# 12969  22301226  POR vs. DAL  2023-12-08         0  1492.541584  1361.139964
# 12970  22301227  BOS vs. NYK  2023-12-08         1  1591.374004  1662.122050
# 12971  22301228  PHX vs. SAC  2023-12-08         0  1526.069995  1551.810711
# 12972  22301229  MIL vs. IND  2023-12-07         0  1502.061541  1601.142185
# 12973  22301230  LAL vs. NOP  2023-12-07         1  1543.760516  1541.467385
#
# ...

# %%
data_type = {"gameId": str, "teamId": str}
team_stat_flatten = pd.read_csv('../dataset/team_stat_flatten_L40.csv', dtype=data_type )
team_stat_flatten
# Out:
#          gameId         DUEL   GAME_DATE  HOME_WON        H_ELO        A_ELO  \
# 0      21300018  CHI vs. NYK  2013-10-31         1  1582.133300  1516.608800
# 1      21300019  LAC vs. GSW  2013-10-31         1  1574.897700  1575.414200
# 2      21300020  CHA vs. CLE  2013-11-01         1  1377.546500  1349.502100
# 3      21300021  ORL vs. NOP  2013-11-01         1  1422.004600  1309.402000
# 4      21300022  WAS vs. PHI  2013-11-01         0  1469.418000  1452.716800
# ...         ...          ...         ...       ...          ...          ...
# 12952  22301226  POR vs. DAL  2023-12-08         0  1492.541584  1361.139964
# 12953  22301227  BOS vs. NYK  2023-12-08         1  1591.374004  1662.122050
# 12954  22301228  PHX vs. SAC  2023-12-08         0  1526.069995  1551.810711
# 12955  22301229  MIL vs. IND  2023-12-07         0  1502.061541  1601.142185
# 12956  22301230  LAL vs. NOP  2023-12-07         1  1543.760516  1541.467385
#
# ...

# %%
team_stat_flatten.columns
# Out:
# Index(['gameId', 'DUEL', 'GAME_DATE', 'HOME_WON', 'H_ELO', 'A_ELO',
#        'H_NB_WIN_L40', 'A_NB_WIN_L40', 'H_PCT_3PT_L40', 'A_PCT_3PT_L40',
#        'H_PCT_LANCER_FRANC_L40', 'A_PCT_LANCER_FRANC_L40',
#        'H_PCT_TIR_REUSSI_L40', 'A_PCT_TIR_REUSSI_L40', 'H_PIE_L40',
#        'A_PIE_L40', 'H_assistPercentage_L40', 'A_assistPercentage_L40',
#        'H_assistRatio_L40', 'A_assistRatio_L40', 'H_assistToTurnover_L40',
#        'A_assistToTurnover_L40', 'H_defensiveRating_L40',
#        'A_defensiveRating_L40', 'H_effectiveFieldGoalPercentage_L40',
#        'A_effectiveFieldGoalPercentage_L40', 'H_estimatedDefensiveRating_L40',
#        'A_estimatedDefensiveRating_L40', 'H_estimatedNetRating_L40',
#        'A_estimatedNetRating_L40', 'H_estimatedOffensiveRating_L40',
#        'A_estimatedOffensiveRating_L40', 'H_estimatedPace_L40',
#        'A_estimatedPace_L40', 'H_estimatedTeamTurnoverPercentage_L40',
#        'A_estimatedTeamTurnoverPercentage_L40', 'H_netRating_L40',
# ...

# %%
team_stat_flatten = team_stat_flatten.drop(columns=['DUEL', 'GAME_DATE','H_teamId', 'A_teamId'])
colonne_a_supprimer = team_stat_flatten.columns[2:]
# Boucle sur chaque paire de colonnes pour calculer la différence
for colonne in colonne_a_supprimer:
    # Extraire le préfixe de la colonne ('H_' ou 'A_')
    prefixe = colonne[0:2]
    # Extraire le nom de la colonne sans le préfixe
    nom_colonne = colonne[2:]
    # Créer une nouvelle colonne pour stocker la différence
    team_stat_flatten[f'{nom_colonne}'] = team_stat_flatten.apply(lambda row: row[f'H_{nom_colonne}'] - row[f'A_{nom_colonne}'], axis=1)

team_stat_flatten = team_stat_flatten.drop(columns=colonne_a_supprimer)
       
team_stat_flatten
# Out:
#          gameId  HOME_WON         ELO  NB_WIN_L40  PCT_3PT_L40  \
# 0      21300018         1   65.524500          -1     0.038000
# 1      21300019         1   -0.516500          -1    -0.175000
# 2      21300020         1   28.044400          -1     0.067000
# 3      21300021         1  112.602600           0    -0.033000
# 4      21300022         0   16.701200          -1     0.019000
# ...         ...       ...         ...         ...          ...
# 12952  22301226         0  131.401620          -8    -0.039575
# 12953  22301227         1  -70.748046           4    -0.005000
# 12954  22301228         0  -25.740716           0     0.009100
# 12955  22301229         0  -99.080644           8    -0.000925
# 12956  22301230         1    2.293131           3    -0.033600
#
#        PCT_LANCER_FRANC_L40  PCT_TIR_REUSSI_L40   PIE_L40  \
# 0                 -0.099000           -0.085000 -0.188000
# 1                 -0.218000           -0.041000 -0.206000
# ...

# %%
team_stat_flatten.to_csv('../dataset/final_dataset_diff_L40.csv', index=False)
