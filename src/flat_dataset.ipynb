# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
data_type = {"gameId": str, "teamId": str}
df_stat_last_10 = pd.read_csv('../dataset/team_stat_last_10.csv', dtype=data_type )
df_stat_last_10
# Out:
#          gameId      teamId   GAME_DATE         DUEL WL  NB_WIN  \
# 0      21300001  1610612754  2013-10-29  IND vs. ORL  W       0
# 1      21300001  1610612753  2013-10-29    ORL @ IND  L       0
# 2      21300002  1610612748  2013-10-29  MIA vs. CHI  W       0
# 3      21300002  1610612741  2013-10-29    CHI @ MIA  L       0
# 4      21300003  1610612747  2013-10-29  LAL vs. LAC  W       0
# ...         ...         ...         ...          ... ..     ...
# 25943  22301228  1610612758  2023-12-08    SAC @ PHX  W       6
# 25944  22301229  1610612749  2023-12-07  MIL vs. IND  L       8
# 25945  22301229  1610612754  2023-12-07    IND @ MIL  W       5
# 25946  22301230  1610612747  2023-12-07  LAL vs. NOP  W       7
# 25947  22301230  1610612740  2023-12-07    NOP @ LAL  L       6
#
#        PCT_TIR_REUSSI_L10  PCT_3PTS_L10  PCT_LANCER_FRANC_L10  \
# 0                     NaN           NaN                   NaN
# 1                     NaN           NaN                   NaN
# 2                     NaN           NaN                   NaN
# 3                     NaN           NaN                   NaN
# 4                     NaN           NaN                   NaN
# ...                   ...           ...                   ...
# 25943              0.4738        0.3759                0.7684
# 25944              0.5201        0.3984                0.7737
# 25945              0.5218        0.3864                0.7809
# 25946              0.4767        0.3244                0.7606
# 25947              0.5006        0.3545                0.7908
#
#        estimatedOffensiveRating_L10  ...  assistToTurnover_L10  \
# 0                               NaN  ...                   NaN
# 1                               NaN  ...                   NaN
# 2                               NaN  ...                   NaN
# 3                               NaN  ...                   NaN
# 4                               NaN  ...                   NaN
# ...                             ...  ...                   ...
# 25943                        114.96  ...                 2.129
# 25944                        122.88  ...                 2.454
# 25945                        121.79  ...                 2.735
# 25946                        108.47  ...                 1.895
# 25947                        118.61  ...                 2.203
#
#        assistRatio_L10  estimatedTeamTurnoverPercentage_L10  \
# 0                  NaN                                  NaN
# 1                  NaN                                  NaN
# 2                  NaN                                  NaN
# 3                  NaN                                  NaN
# 4                  NaN                                  NaN
# ...                ...                                  ...
# 25943            19.61                              12.9317
# 25944            19.75                              12.1841
# 25945            20.45                              11.1999
# 25946            19.35                              14.3494
# 25947            19.92                              13.3914
#
#        turnoverRatio_L10  effectiveFieldGoalPercentage_L10  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
# ...                  ...                               ...
# 25943              13.14                            0.5591
# 25944              12.30                            0.6027
# 25945              11.57                            0.6012
# 25946              14.62                            0.5325
# 25947              13.51                            0.5590
#
#        trueShootingPercentage_L10  estimatedPace_L10  pace_L10  pacePer40_L10  \
# 0                             NaN                NaN       NaN            NaN
# 1                             NaN                NaN       NaN            NaN
# 2                             NaN                NaN       NaN            NaN
# 3                             NaN                NaN       NaN            NaN
# 4                             NaN                NaN       NaN            NaN
# ...                           ...                ...       ...            ...
# 25943                      0.5941            103.950   102.400         85.334
# 25944                      0.6296            104.243   102.598         85.498
# 25945                      0.6305            107.508   104.300         86.917
# 25946                      0.5706            102.164   100.750         83.959
# 25947                      0.6015            100.766    98.950         82.459
#
#        PIE_L10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 25943   0.4814
# 25944   0.5446
# 25945   0.5054
# 25946   0.5255
# 25947   0.5425
#
# [25948 rows x 26 columns]

# %%
df_stat_last_10['col'] = df_stat_last_10.groupby('gameId').cumcount() + 1
df_stat_flatten = df_stat_last_10.pivot_table(index='gameId', columns=df_stat_last_10.groupby('gameId').cumcount() + 1, values=['teamId', 'GAME_DATE', 'DUEL', 'WL', 'NB_WIN',
       'PCT_TIR_REUSSI_L10', 'PCT_3PTS_L10', 'PCT_LANCER_FRANC_L10',
       'estimatedOffensiveRating_L10', 'offensiveRating_L10',
       'estimatedDefensiveRating_L10', 'defensiveRating_L10',
       'estimatedNetRating_L10', 'netRating_L10', 'assistPercentage_L10',
       'assistToTurnover_L10', 'assistRatio_L10',
       'estimatedTeamTurnoverPercentage_L10', 'turnoverRatio_L10',
       'effectiveFieldGoalPercentage_L10', 'trueShootingPercentage_L10',
       'estimatedPace_L10', 'pace_L10', 'pacePer40_L10', 'PIE_L10'], aggfunc='first')

df_stat_flatten.columns = [f'col{col[1]}' for col in df_stat_flatten.columns]


df_stat_flatten = df_stat_flatten.reset_index()
#df_stat_flatten

# %%
df_stat_flatten
# Out:
#          gameId         col1       col2        col1        col2  col1  col2  \
# 0      21300001  IND vs. ORL  ORL @ IND  2013-10-29  2013-10-29     0     0
# 1      21300002  MIA vs. CHI  CHI @ MIA  2013-10-29  2013-10-29     0     0
# 2      21300003  LAL vs. LAC  LAC @ LAL  2013-10-29  2013-10-29     0     0
# 3      21300004  CLE vs. BKN  BKN @ CLE  2013-10-30  2013-10-30     0     0
# 4      21300005  PHI vs. MIA  MIA @ PHI  2013-10-30  2013-10-30     0     1
# ...         ...          ...        ...         ...         ...   ...   ...
# 12969  22301226  POR vs. DAL  DAL @ POR  2023-12-08  2023-12-08     3     4
# 12970  22301227  BOS vs. NYK  NYK @ BOS  2023-12-08  2023-12-08     7     7
# 12971  22301228  PHX vs. SAC  SAC @ PHX  2023-12-08  2023-12-08     7     6
# 12972  22301229  MIL vs. IND  IND @ MIL  2023-12-07  2023-12-07     8     5
# 12973  22301230  LAL vs. NOP  NOP @ LAL  2023-12-07  2023-12-07     7     6
#
#          col1    col2    col1  ...    col1    col2     col1    col2  \
# 0         NaN     NaN     NaN  ...     NaN     NaN      NaN     NaN
# 1         NaN     NaN     NaN  ...     NaN     NaN      NaN     NaN
# 2         NaN     NaN     NaN  ...     NaN     NaN      NaN     NaN
# 3         NaN     NaN     NaN  ...     NaN     NaN      NaN     NaN
# 4         NaN  0.5500     NaN  ...     NaN  82.080      NaN   98.50
# ...       ...     ...     ...  ...     ...     ...      ...     ...
# 12969  0.3744  0.3463  0.7976  ...  81.051  83.168   97.259   99.80
# 12970  0.3545  0.3853  0.7753  ...  82.192  80.624   98.631   96.75
# 12971  0.3954  0.3759  0.8557  ...  80.209  85.334   96.250  102.40
# 12972  0.3984  0.3864  0.7737  ...  85.498  86.917  102.598  104.30
# 12973  0.3244  0.3545  0.7606  ...  83.959  82.459  100.750   98.95
#
#              col1        col2    col1    col2   col1   col2
# 0      1610612754  1610612753     NaN     NaN    NaN    NaN
# 1      1610612748  1610612741     NaN     NaN    NaN    NaN
# 2      1610612747  1610612746     NaN     NaN    NaN    NaN
# 3      1610612739  1610612751     NaN     NaN    NaN    NaN
# 4      1610612755  1610612748     NaN  0.6310    NaN  20.20
# ...           ...         ...     ...     ...    ...    ...
# 12969  1610612757  1610612742  0.5395  0.5587  16.22  10.72
# 12970  1610612738  1610612752  0.5876  0.5792  15.05  13.69
# 12971  1610612756  1610612758  0.6058  0.5941  14.64  13.14
# 12972  1610612749  1610612754  0.6296  0.6305  12.30  11.57
# 12973  1610612747  1610612740  0.5706  0.6015  14.62  13.51
#
# [12974 rows x 51 columns]

# %%
print(len(['DUEL', 'GAME_DATE', 'NB_WIN', 'PCT_3PT_L10', 'PCT_LANCER_FRANC_L10', 'PCT_TIR_REUSSI_L10', 'PIE_L10', 'WL', 'assistPercentage_L10', 'assistRatio_L10', 'assistToTurnover_L10', 'defensiveRating_L10', 'effectiveFieldGoalPercentage_L10', 'estimatedDefensiveRating_L10', 'estimatedNetRating_L10', 'estimatedOffensiveRating_L10', 'estimatedPace_L10', 'estimatedTeamTurnoverPercentage_L10', 'netRating_L10', 'offensiveRating_L10','pacePer40_L10', 'pace_L10','teamId', 'trueShootingPercentage_L10', 'turnoverRatio_L10']))
# Out:
# 25

# %%
df_stat_flatten.columns = ['gameId', 'H_DUEL', 'A_DUEL', 'H_GAME_DATE', 'A_GAME_DATE', 'H_NB_WIN', 'A_NB_WIN', 'H_PCT_3PT_L10', 'A_PCT_3PT_L10', 'H_PCT_LANCER_FRANC_L10', 'A_PCT_LANCER_FRANC_L10', 'H_PCT_TIR_REUSSI_L10', 'A_PCT_TIR_REUSSI_L10', 'H_PIE_L10', 'A_PIE_L10', 'H_WL', 'A_WL', 'H_assistPercentage_L10', 'A_assistPercentage_L10', 'H_assistRatio_L10', 'A_assistRatio_L10', 'H_assistToTurnover_L10', 'A_assistToTurnover_L10', 'H_defensiveRating_L10', 'A_defensiveRating_L10', 'H_effectiveFieldGoalPercentage_L10', 'A_effectiveFieldGoalPercentage_L10', 'H_estimatedDefensiveRating_L10', 'A_estimatedDefensiveRating_L10', 'H_estimatedNetRating_L10', 'A_estimatedNetRating_L10', 'H_estimatedOffensiveRating_L10', 'A_estimatedOffensiveRating_L10', 'H_estimatedPace_L10', 'A_estimatedPace_L10', 'H_estimatedTeamTurnoverPercentage_L10', 'A_estimatedTeamTurnoverPercentage_L10', 'H_netRating_L10', 'A_netRating_L10', 'H_offensiveRating_L10', 'A_offensiveRating_L10', 'H_pacePer40_L10', 'A_pacePer40_L10', 'H_pace_L10', 'A_pace_L10', 'H_teamId', 'A_teamId', 'H_trueShootingPercentage_L10', 'A_trueShootingPercentage_L10', 'H_turnoverRatio_L10', 'A_turnoverRatio_L10']
df_stat_flatten
# Out:
#          gameId       H_DUEL     A_DUEL H_GAME_DATE A_GAME_DATE  H_NB_WIN  \
# 0      21300001  IND vs. ORL  ORL @ IND  2013-10-29  2013-10-29         0
# 1      21300002  MIA vs. CHI  CHI @ MIA  2013-10-29  2013-10-29         0
# 2      21300003  LAL vs. LAC  LAC @ LAL  2013-10-29  2013-10-29         0
# 3      21300004  CLE vs. BKN  BKN @ CLE  2013-10-30  2013-10-30         0
# 4      21300005  PHI vs. MIA  MIA @ PHI  2013-10-30  2013-10-30         0
# ...         ...          ...        ...         ...         ...       ...
# 12969  22301226  POR vs. DAL  DAL @ POR  2023-12-08  2023-12-08         3
# 12970  22301227  BOS vs. NYK  NYK @ BOS  2023-12-08  2023-12-08         7
# 12971  22301228  PHX vs. SAC  SAC @ PHX  2023-12-08  2023-12-08         7
# 12972  22301229  MIL vs. IND  IND @ MIL  2023-12-07  2023-12-07         8
# 12973  22301230  LAL vs. NOP  NOP @ LAL  2023-12-07  2023-12-07         7
#
#        A_NB_WIN  H_PCT_3PT_L10  A_PCT_3PT_L10  H_PCT_LANCER_FRANC_L10  ...  \
# 0             0            NaN            NaN                     NaN  ...
# 1             0            NaN            NaN                     NaN  ...
# 2             0            NaN            NaN                     NaN  ...
# 3             0            NaN            NaN                     NaN  ...
# 4             1            NaN         0.5500                     NaN  ...
# ...         ...            ...            ...                     ...  ...
# 12969         4         0.3744         0.3463                  0.7976  ...
# 12970         7         0.3545         0.3853                  0.7753  ...
# 12971         6         0.3954         0.3759                  0.8557  ...
# 12972         5         0.3984         0.3864                  0.7737  ...
# 12973         6         0.3244         0.3545                  0.7606  ...
#
#        H_pacePer40_L10  A_pacePer40_L10  H_pace_L10  A_pace_L10    H_teamId  \
# 0                  NaN              NaN         NaN         NaN  1610612754
# 1                  NaN              NaN         NaN         NaN  1610612748
# 2                  NaN              NaN         NaN         NaN  1610612747
# 3                  NaN              NaN         NaN         NaN  1610612739
# 4                  NaN           82.080         NaN       98.50  1610612755
# ...                ...              ...         ...         ...         ...
# 12969           81.051           83.168      97.259       99.80  1610612757
# 12970           82.192           80.624      98.631       96.75  1610612738
# 12971           80.209           85.334      96.250      102.40  1610612756
# 12972           85.498           86.917     102.598      104.30  1610612749
# 12973           83.959           82.459     100.750       98.95  1610612747
#
#          A_teamId H_trueShootingPercentage_L10  A_trueShootingPercentage_L10  \
# 0      1610612753                          NaN                           NaN
# 1      1610612741                          NaN                           NaN
# 2      1610612746                          NaN                           NaN
# 3      1610612751                          NaN                           NaN
# 4      1610612748                          NaN                        0.6310
# ...           ...                          ...                           ...
# 12969  1610612742                       0.5395                        0.5587
# 12970  1610612752                       0.5876                        0.5792
# 12971  1610612758                       0.6058                        0.5941
# 12972  1610612754                       0.6296                        0.6305
# 12973  1610612740                       0.5706                        0.6015
#
#        H_turnoverRatio_L10  A_turnoverRatio_L10
# 0                      NaN                  NaN
# 1                      NaN                  NaN
# 2                      NaN                  NaN
# 3                      NaN                  NaN
# 4                      NaN                20.20
# ...                    ...                  ...
# 12969                16.22                10.72
# 12970                15.05                13.69
# 12971                14.64                13.14
# 12972                12.30                11.57
# 12973                14.62                13.51
#
# [12974 rows x 51 columns]

# %%
df_stat_flatten = df_stat_flatten.drop('A_DUEL', axis=1)
df_stat_flatten = df_stat_flatten.drop('A_GAME_DATE', axis=1)
df_stat_flatten = df_stat_flatten.drop('A_WL', axis=1)
df_stat_flatten = df_stat_flatten.rename(columns={'H_DUEL': 'DUEL', 'H_GAME_DATE': 'GAME_DATE', 'H_WL': 'HOME_WON'})
df_stat_flatten['HOME_WON'] = df_stat_flatten['HOME_WON'].replace('W', 1)
df_stat_flatten['HOME_WON'] = df_stat_flatten['HOME_WON'].replace('L', 0)
df_stat_flatten
# Out:
#          gameId         DUEL   GAME_DATE  H_NB_WIN  A_NB_WIN  H_PCT_3PT_L10  \
# 0      21300001  IND vs. ORL  2013-10-29         0         0            NaN
# 1      21300002  MIA vs. CHI  2013-10-29         0         0            NaN
# 2      21300003  LAL vs. LAC  2013-10-29         0         0            NaN
# 3      21300004  CLE vs. BKN  2013-10-30         0         0            NaN
# 4      21300005  PHI vs. MIA  2013-10-30         0         1            NaN
# ...         ...          ...         ...       ...       ...            ...
# 12969  22301226  POR vs. DAL  2023-12-08         3         4         0.3744
# 12970  22301227  BOS vs. NYK  2023-12-08         7         7         0.3545
# 12971  22301228  PHX vs. SAC  2023-12-08         7         6         0.3954
# 12972  22301229  MIL vs. IND  2023-12-07         8         5         0.3984
# 12973  22301230  LAL vs. NOP  2023-12-07         7         6         0.3244
#
#        A_PCT_3PT_L10  H_PCT_LANCER_FRANC_L10  A_PCT_LANCER_FRANC_L10  \
# 0                NaN                     NaN                     NaN
# 1                NaN                     NaN                     NaN
# 2                NaN                     NaN                     NaN
# 3                NaN                     NaN                     NaN
# 4             0.5500                     NaN                  0.7590
# ...              ...                     ...                     ...
# 12969         0.3463                  0.7976                  0.7192
# 12970         0.3853                  0.7753                  0.7832
# 12971         0.3759                  0.8557                  0.7684
# 12972         0.3864                  0.7737                  0.7809
# 12973         0.3545                  0.7606                  0.7908
#
#        H_PCT_TIR_REUSSI_L10  ...  H_pacePer40_L10  A_pacePer40_L10  \
# 0                       NaN  ...              NaN              NaN
# 1                       NaN  ...              NaN              NaN
# 2                       NaN  ...              NaN              NaN
# 3                       NaN  ...              NaN              NaN
# 4                       NaN  ...              NaN           82.080
# ...                     ...  ...              ...              ...
# 12969                0.4321  ...           81.051           83.168
# 12970                0.4698  ...           82.192           80.624
# 12971                0.4796  ...           80.209           85.334
# 12972                0.5201  ...           85.498           86.917
# 12973                0.4767  ...           83.959           82.459
#
#        H_pace_L10  A_pace_L10    H_teamId    A_teamId  \
# 0             NaN         NaN  1610612754  1610612753
# 1             NaN         NaN  1610612748  1610612741
# 2             NaN         NaN  1610612747  1610612746
# 3             NaN         NaN  1610612739  1610612751
# 4             NaN       98.50  1610612755  1610612748
# ...           ...         ...         ...         ...
# 12969      97.259       99.80  1610612757  1610612742
# 12970      98.631       96.75  1610612738  1610612752
# 12971      96.250      102.40  1610612756  1610612758
# 12972     102.598      104.30  1610612749  1610612754
# 12973     100.750       98.95  1610612747  1610612740
#
#        H_trueShootingPercentage_L10  A_trueShootingPercentage_L10  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                        0.6310
# ...                             ...                           ...
# 12969                        0.5395                        0.5587
# 12970                        0.5876                        0.5792
# 12971                        0.6058                        0.5941
# 12972                        0.6296                        0.6305
# 12973                        0.5706                        0.6015
#
#        H_turnoverRatio_L10  A_turnoverRatio_L10
# 0                      NaN                  NaN
# 1                      NaN                  NaN
# 2                      NaN                  NaN
# 3                      NaN                  NaN
# 4                      NaN                20.20
# ...                    ...                  ...
# 12969                16.22                10.72
# 12970                15.05                13.69
# 12971                14.64                13.14
# 12972                12.30                11.57
# 12973                14.62                13.51
#
# [12974 rows x 48 columns]

# %%
df_stat_flatten.to_csv('../dataset/team_stat_flatten.csv', index=False)

# %%
nba_elo = pd.read_csv('../dataset/nba_elo.csv', dtype=data_type )

# %%
nba_elo_copy= nba_elo.copy()
nba_elo_copy
# Out:
#               date  season  neutral playoff team1 team2     elo1_pre  \
# 0       1946-11-01    1947        0     NaN   TRH   NYK  1300.000000
# 1       1946-11-01    1947        0     NaN   NYK   TRH  1300.000000
# 2       1946-11-02    1947        0     NaN   PRO   BOS  1300.000000
# 3       1946-11-02    1947        0     NaN   STB   PIT  1300.000000
# 4       1946-11-02    1947        0     NaN   CHS   NYK  1300.000000
# ...            ...     ...      ...     ...   ...   ...          ...
# 148933  2024-03-30    2024        0     NaN   MEM   ORL  1325.023208
# 148934  2024-03-30    2024        0     NaN   MIL   ATL  1586.179279
# 148935  2024-03-30    2024        0     NaN   NOP   BOS  1635.324867
# 148936  2024-03-30    2024        0     NaN   ORL   MEM  1523.156879
# 148937  2024-03-30    2024        0     NaN   ATL   MIL  1493.120229
#
#            elo2_pre  elo_prob1  elo_prob2    elo1_post    elo2_post  score1  \
# 0       1300.000000   0.640065   0.359935  1293.276700  1306.723300      66
# 1       1300.000000   0.359935   0.640065  1306.723300  1293.276700      68
# 2       1300.000000   0.640065   0.359935  1305.154200  1294.845800      59
# 3       1300.000000   0.640065   0.359935  1304.690800  1295.309200      56
# 4       1306.723300   0.631101   0.368899  1309.652100  1297.071200      63
# ...             ...        ...        ...          ...          ...     ...
# 148933  1523.156879   0.152362   0.847638  1319.643511  1528.536576      88
# 148934  1493.120229   0.490012   0.509988  1596.162979  1483.136529     122
# 148935  1758.207851   0.467116   0.532884  1624.649366  1768.883352      92
# 148936  1325.023208   0.847638   0.152362  1528.536576  1319.643511     118
# 148937  1586.179279   0.509988   0.490012  1483.136529  1596.162979     113
#
#         score2  is_home
# 0           68        1
# 1           66        0
# 2           53        1
# 3           51        1
# 4           47        1
# ...        ...      ...
# 148933     118        0
# 148934     113        0
# 148935     104        1
# 148936      88        1
# 148937     122        1
#
# [148938 rows x 15 columns]

# %%
columns_list = nba_elo_copy.columns.tolist()

print(columns_list)
# Out:
# ['date', 'season', 'neutral', 'playoff', 'team1', 'team2', 'elo1_pre', 'elo2_pre', 'elo_prob1', 'elo_prob2', 'elo1_post', 'elo2_post', 'score1', 'score2', 'is_home']

# %%
columns_to_drop = ['season',  'neutral', 'playoff', 'team2', 'elo1_post', 'elo2_post', 'score1', 'score2', 'is_home']  # Liste des noms des colonnes à supprimer
nba_elo_copy_drop= nba_elo_copy.drop(columns=columns_to_drop)

# %%
nba_elo_copy_drop
# Out:
#               date team1     elo1_pre     elo2_pre  elo_prob1  elo_prob2
# 0       1946-11-01   TRH  1300.000000  1300.000000   0.640065   0.359935
# 1       1946-11-01   NYK  1300.000000  1300.000000   0.359935   0.640065
# 2       1946-11-02   PRO  1300.000000  1300.000000   0.640065   0.359935
# 3       1946-11-02   STB  1300.000000  1300.000000   0.640065   0.359935
# 4       1946-11-02   CHS  1300.000000  1306.723300   0.631101   0.368899
# ...            ...   ...          ...          ...        ...        ...
# 148933  2024-03-30   MEM  1325.023208  1523.156879   0.152362   0.847638
# 148934  2024-03-30   MIL  1586.179279  1493.120229   0.490012   0.509988
# 148935  2024-03-30   NOP  1635.324867  1758.207851   0.467116   0.532884
# 148936  2024-03-30   ORL  1523.156879  1325.023208   0.847638   0.152362
# 148937  2024-03-30   ATL  1493.120229  1586.179279   0.509988   0.490012
#
# [148938 rows x 6 columns]

# %%
nba_elo_copy_drop['team1'] = nba_elo_copy_drop['team1'].replace({'PHO': 'PHX', 'BRK': 'BKN', 'CHO': 'CHA'})

# %%
df_stat_flatten['team1'] = df_stat_flatten['DUEL'].str.split(' vs. ').str[0]

# %%
df_stat_flatten
# Out:
#          gameId         DUEL   GAME_DATE  H_NB_WIN  A_NB_WIN  H_PCT_3PT_L10  \
# 0      21300001  IND vs. ORL  2013-10-29         0         0            NaN
# 1      21300002  MIA vs. CHI  2013-10-29         0         0            NaN
# 2      21300003  LAL vs. LAC  2013-10-29         0         0            NaN
# 3      21300004  CLE vs. BKN  2013-10-30         0         0            NaN
# 4      21300005  PHI vs. MIA  2013-10-30         0         1            NaN
# ...         ...          ...         ...       ...       ...            ...
# 12969  22301226  POR vs. DAL  2023-12-08         3         4         0.3744
# 12970  22301227  BOS vs. NYK  2023-12-08         7         7         0.3545
# 12971  22301228  PHX vs. SAC  2023-12-08         7         6         0.3954
# 12972  22301229  MIL vs. IND  2023-12-07         8         5         0.3984
# 12973  22301230  LAL vs. NOP  2023-12-07         7         6         0.3244
#
#        A_PCT_3PT_L10  H_PCT_LANCER_FRANC_L10  A_PCT_LANCER_FRANC_L10  \
# 0                NaN                     NaN                     NaN
# 1                NaN                     NaN                     NaN
# 2                NaN                     NaN                     NaN
# 3                NaN                     NaN                     NaN
# 4             0.5500                     NaN                  0.7590
# ...              ...                     ...                     ...
# 12969         0.3463                  0.7976                  0.7192
# 12970         0.3853                  0.7753                  0.7832
# 12971         0.3759                  0.8557                  0.7684
# 12972         0.3864                  0.7737                  0.7809
# 12973         0.3545                  0.7606                  0.7908
#
#        H_PCT_TIR_REUSSI_L10  ...  A_pacePer40_L10  H_pace_L10  A_pace_L10  \
# 0                       NaN  ...              NaN         NaN         NaN
# 1                       NaN  ...              NaN         NaN         NaN
# 2                       NaN  ...              NaN         NaN         NaN
# 3                       NaN  ...              NaN         NaN         NaN
# 4                       NaN  ...           82.080         NaN       98.50
# ...                     ...  ...              ...         ...         ...
# 12969                0.4321  ...           83.168      97.259       99.80
# 12970                0.4698  ...           80.624      98.631       96.75
# 12971                0.4796  ...           85.334      96.250      102.40
# 12972                0.5201  ...           86.917     102.598      104.30
# 12973                0.4767  ...           82.459     100.750       98.95
#
#          H_teamId    A_teamId  H_trueShootingPercentage_L10  \
# 0      1610612754  1610612753                           NaN
# 1      1610612748  1610612741                           NaN
# 2      1610612747  1610612746                           NaN
# 3      1610612739  1610612751                           NaN
# 4      1610612755  1610612748                           NaN
# ...           ...         ...                           ...
# 12969  1610612757  1610612742                        0.5395
# 12970  1610612738  1610612752                        0.5876
# 12971  1610612756  1610612758                        0.6058
# 12972  1610612749  1610612754                        0.6296
# 12973  1610612747  1610612740                        0.5706
#
#        A_trueShootingPercentage_L10  H_turnoverRatio_L10  A_turnoverRatio_L10  \
# 0                               NaN                  NaN                  NaN
# 1                               NaN                  NaN                  NaN
# 2                               NaN                  NaN                  NaN
# 3                               NaN                  NaN                  NaN
# 4                            0.6310                  NaN                20.20
# ...                             ...                  ...                  ...
# 12969                        0.5587                16.22                10.72
# 12970                        0.5792                15.05                13.69
# 12971                        0.5941                14.64                13.14
# 12972                        0.6305                12.30                11.57
# 12973                        0.6015                14.62                13.51
#
#        team1
# 0        IND
# 1        MIA
# 2        LAL
# 3        CLE
# 4        PHI
# ...      ...
# 12969    POR
# 12970    BOS
# 12971    PHX
# 12972    MIL
# 12973    LAL
#
# [12974 rows x 49 columns]

# %%
new_column_names = {'date':'GAME_DATE' }
nba_elo_copy_drop_rename= nba_elo_copy_drop.rename(columns=new_column_names)
nba_elo_copy_drop_rename
# Out:
#          GAME_DATE team1     elo1_pre     elo2_pre  elo_prob1  elo_prob2
# 0       1946-11-01   TRH  1300.000000  1300.000000   0.640065   0.359935
# 1       1946-11-01   NYK  1300.000000  1300.000000   0.359935   0.640065
# 2       1946-11-02   PRO  1300.000000  1300.000000   0.640065   0.359935
# 3       1946-11-02   STB  1300.000000  1300.000000   0.640065   0.359935
# 4       1946-11-02   CHS  1300.000000  1306.723300   0.631101   0.368899
# ...            ...   ...          ...          ...        ...        ...
# 148933  2024-03-30   MEM  1325.023208  1523.156879   0.152362   0.847638
# 148934  2024-03-30   MIL  1586.179279  1493.120229   0.490012   0.509988
# 148935  2024-03-30   NOP  1635.324867  1758.207851   0.467116   0.532884
# 148936  2024-03-30   ORL  1523.156879  1325.023208   0.847638   0.152362
# 148937  2024-03-30   ATL  1493.120229  1586.179279   0.509988   0.490012
#
# [148938 rows x 6 columns]

# %%
result = pd.merge(df_stat_flatten, nba_elo_copy_drop_rename, on=['GAME_DATE', 'team1'])

# %%
result
# Out:
#          gameId         DUEL   GAME_DATE  H_NB_WIN  A_NB_WIN  H_PCT_3PT_L10  \
# 0      21300001  IND vs. ORL  2013-10-29         0         0            NaN
# 1      21300002  MIA vs. CHI  2013-10-29         0         0            NaN
# 2      21300003  LAL vs. LAC  2013-10-29         0         0            NaN
# 3      21300004  CLE vs. BKN  2013-10-30         0         0            NaN
# 4      21300005  PHI vs. MIA  2013-10-30         0         1            NaN
# ...         ...          ...         ...       ...       ...            ...
# 12969  22301226  POR vs. DAL  2023-12-08         3         4         0.3744
# 12970  22301227  BOS vs. NYK  2023-12-08         7         7         0.3545
# 12971  22301228  PHX vs. SAC  2023-12-08         7         6         0.3954
# 12972  22301229  MIL vs. IND  2023-12-07         8         5         0.3984
# 12973  22301230  LAL vs. NOP  2023-12-07         7         6         0.3244
#
#        A_PCT_3PT_L10  H_PCT_LANCER_FRANC_L10  A_PCT_LANCER_FRANC_L10  \
# 0                NaN                     NaN                     NaN
# 1                NaN                     NaN                     NaN
# 2                NaN                     NaN                     NaN
# 3                NaN                     NaN                     NaN
# 4             0.5500                     NaN                  0.7590
# ...              ...                     ...                     ...
# 12969         0.3463                  0.7976                  0.7192
# 12970         0.3853                  0.7753                  0.7832
# 12971         0.3759                  0.8557                  0.7684
# 12972         0.3864                  0.7737                  0.7809
# 12973         0.3545                  0.7606                  0.7908
#
#        H_PCT_TIR_REUSSI_L10  ...    A_teamId  H_trueShootingPercentage_L10  \
# 0                       NaN  ...  1610612753                           NaN
# 1                       NaN  ...  1610612741                           NaN
# 2                       NaN  ...  1610612746                           NaN
# 3                       NaN  ...  1610612751                           NaN
# 4                       NaN  ...  1610612748                           NaN
# ...                     ...  ...         ...                           ...
# 12969                0.4321  ...  1610612742                        0.5395
# 12970                0.4698  ...  1610612752                        0.5876
# 12971                0.4796  ...  1610612758                        0.6058
# 12972                0.5201  ...  1610612754                        0.6296
# 12973                0.4767  ...  1610612740                        0.5706
#
#        A_trueShootingPercentage_L10  H_turnoverRatio_L10  A_turnoverRatio_L10  \
# 0                               NaN                  NaN                  NaN
# 1                               NaN                  NaN                  NaN
# 2                               NaN                  NaN                  NaN
# 3                               NaN                  NaN                  NaN
# 4                            0.6310                  NaN                20.20
# ...                             ...                  ...                  ...
# 12969                        0.5587                16.22                10.72
# 12970                        0.5792                15.05                13.69
# 12971                        0.5941                14.64                13.14
# 12972                        0.6305                12.30                11.57
# 12973                        0.6015                14.62                13.51
#
#        team1     elo1_pre     elo2_pre  elo_prob1  elo_prob2
# 0        IND  1583.572100  1313.231700   0.893961   0.106039
# 1        MIA  1691.889600  1519.912400   0.827159   0.172841
# 2        LAL  1511.020000  1586.588400   0.535102   0.464898
# 3        CLE  1369.282300  1548.436500   0.388019   0.611981
# 4        PHI  1459.690400  1695.193200   0.314316   0.685684
# ...      ...          ...          ...        ...        ...
# 12969    POR  1361.139964  1492.541584   0.454932   0.545068
# 12970    BOS  1662.122050  1591.374004   0.727684   0.272316
# 12971    PHX  1551.810711  1526.069995   0.673448   0.326552
# 12972    MIL  1601.142185  1502.061541   0.638845   0.361155
# 12973    LAL  1541.467385  1543.760516   0.496700   0.503300
#
# [12974 rows x 53 columns]

# %%
new_column_names = {'elo1_pre':'H_ELO' , 'elo2_pre': 'A_ELO', 'elo_prob1':'H_ELO_PROB', 'elo_prob2':'A_ELO_PROB'}
result= result.rename(columns=new_column_names)
result
# Out:
#          gameId         DUEL   GAME_DATE  H_NB_WIN  A_NB_WIN  H_PCT_3PT_L10  \
# 0      21300001  IND vs. ORL  2013-10-29         0         0            NaN
# 1      21300002  MIA vs. CHI  2013-10-29         0         0            NaN
# 2      21300003  LAL vs. LAC  2013-10-29         0         0            NaN
# 3      21300004  CLE vs. BKN  2013-10-30         0         0            NaN
# 4      21300005  PHI vs. MIA  2013-10-30         0         1            NaN
# ...         ...          ...         ...       ...       ...            ...
# 12969  22301226  POR vs. DAL  2023-12-08         3         4         0.3744
# 12970  22301227  BOS vs. NYK  2023-12-08         7         7         0.3545
# 12971  22301228  PHX vs. SAC  2023-12-08         7         6         0.3954
# 12972  22301229  MIL vs. IND  2023-12-07         8         5         0.3984
# 12973  22301230  LAL vs. NOP  2023-12-07         7         6         0.3244
#
#        A_PCT_3PT_L10  H_PCT_LANCER_FRANC_L10  A_PCT_LANCER_FRANC_L10  \
# 0                NaN                     NaN                     NaN
# 1                NaN                     NaN                     NaN
# 2                NaN                     NaN                     NaN
# 3                NaN                     NaN                     NaN
# 4             0.5500                     NaN                  0.7590
# ...              ...                     ...                     ...
# 12969         0.3463                  0.7976                  0.7192
# 12970         0.3853                  0.7753                  0.7832
# 12971         0.3759                  0.8557                  0.7684
# 12972         0.3864                  0.7737                  0.7809
# 12973         0.3545                  0.7606                  0.7908
#
#        H_PCT_TIR_REUSSI_L10  ...    A_teamId  H_trueShootingPercentage_L10  \
# 0                       NaN  ...  1610612753                           NaN
# 1                       NaN  ...  1610612741                           NaN
# 2                       NaN  ...  1610612746                           NaN
# 3                       NaN  ...  1610612751                           NaN
# 4                       NaN  ...  1610612748                           NaN
# ...                     ...  ...         ...                           ...
# 12969                0.4321  ...  1610612742                        0.5395
# 12970                0.4698  ...  1610612752                        0.5876
# 12971                0.4796  ...  1610612758                        0.6058
# 12972                0.5201  ...  1610612754                        0.6296
# 12973                0.4767  ...  1610612740                        0.5706
#
#        A_trueShootingPercentage_L10  H_turnoverRatio_L10  A_turnoverRatio_L10  \
# 0                               NaN                  NaN                  NaN
# 1                               NaN                  NaN                  NaN
# 2                               NaN                  NaN                  NaN
# 3                               NaN                  NaN                  NaN
# 4                            0.6310                  NaN                20.20
# ...                             ...                  ...                  ...
# 12969                        0.5587                16.22                10.72
# 12970                        0.5792                15.05                13.69
# 12971                        0.5941                14.64                13.14
# 12972                        0.6305                12.30                11.57
# 12973                        0.6015                14.62                13.51
#
#        team1        H_ELO        A_ELO  H_ELO_PROB  A_ELO_PROB
# 0        IND  1583.572100  1313.231700    0.893961    0.106039
# 1        MIA  1691.889600  1519.912400    0.827159    0.172841
# 2        LAL  1511.020000  1586.588400    0.535102    0.464898
# 3        CLE  1369.282300  1548.436500    0.388019    0.611981
# 4        PHI  1459.690400  1695.193200    0.314316    0.685684
# ...      ...          ...          ...         ...         ...
# 12969    POR  1361.139964  1492.541584    0.454932    0.545068
# 12970    BOS  1662.122050  1591.374004    0.727684    0.272316
# 12971    PHX  1551.810711  1526.069995    0.673448    0.326552
# 12972    MIL  1601.142185  1502.061541    0.638845    0.361155
# 12973    LAL  1541.467385  1543.760516    0.496700    0.503300
#
# [12974 rows x 53 columns]

# %%
new_order = ['gameId', 'DUEL','GAME_DATE','HOME_WON','H_ELO','A_ELO','H_ELO_PROB','A_ELO_PROB','H_NB_WIN','A_NB_WIN', 'H_PCT_3PT_L10',
       'A_PCT_3PT_L10', 'H_PCT_LANCER_FRANC_L10', 'A_PCT_LANCER_FRANC_L10',
       'H_PCT_TIR_REUSSI_L10', 'A_PCT_TIR_REUSSI_L10', 'H_PIE_L10',
       'A_PIE_L10',  'H_assistPercentage_L10',
       'A_assistPercentage_L10', 'H_assistRatio_L10', 'A_assistRatio_L10',
       'H_assistToTurnover_L10', 'A_assistToTurnover_L10',
       'H_defensiveRating_L10', 'A_defensiveRating_L10',
       'H_effectiveFieldGoalPercentage_L10',
       'A_effectiveFieldGoalPercentage_L10', 'H_estimatedDefensiveRating_L10',
       'A_estimatedDefensiveRating_L10', 'H_estimatedNetRating_L10',
       'A_estimatedNetRating_L10', 'H_estimatedOffensiveRating_L10',
       'A_estimatedOffensiveRating_L10', 'H_estimatedPace_L10',
       'A_estimatedPace_L10', 'H_estimatedTeamTurnoverPercentage_L10',
       'A_estimatedTeamTurnoverPercentage_L10', 'H_netRating_L10',
       'A_netRating_L10', 'H_offensiveRating_L10', 'A_offensiveRating_L10',
       'H_pacePer40_L10', 'A_pacePer40_L10', 'H_pace_L10', 'A_pace_L10',
       'H_teamId', 'A_teamId', 'H_trueShootingPercentage_L10',
       'A_trueShootingPercentage_L10', 'H_turnoverRatio_L10',
       'A_turnoverRatio_L10', 'team1']

# Réorganiser les colonnes
result = result.reindex(columns=new_order)

# %%
result = result.drop(columns=['team1'])

# %%
result = result.dropna()

# %%
result.to_csv('../dataset/team_stat_flatten.csv', index=False)
result
# Out:
#          gameId         DUEL   GAME_DATE  HOME_WON        H_ELO        A_ELO  \
# 17     21300018  CHI vs. NYK  2013-10-31         1  1516.608800  1582.133300
# 18     21300019  LAC vs. GSW  2013-10-31         1  1575.414200  1574.897700
# 19     21300020  CHA vs. CLE  2013-11-01         1  1349.502100  1377.546500
# 20     21300021  ORL vs. NOP  2013-11-01         1  1309.402000  1422.004600
# 21     21300022  WAS vs. PHI  2013-11-01         0  1452.716800  1469.418000
# ...         ...          ...         ...       ...          ...          ...
# 12969  22301226  POR vs. DAL  2023-12-08         0  1361.139964  1492.541584
# 12970  22301227  BOS vs. NYK  2023-12-08         1  1662.122050  1591.374004
# 12971  22301228  PHX vs. SAC  2023-12-08         0  1551.810711  1526.069995
# 12972  22301229  MIL vs. IND  2023-12-07         0  1601.142185  1502.061541
# 12973  22301230  LAL vs. NOP  2023-12-07         1  1541.467385  1543.760516
#
#        H_ELO_PROB  A_ELO_PROB  H_NB_WIN  A_NB_WIN  ...  H_pacePer40_L10  \
# 17       0.549452    0.450548         0         1  ...           82.080
# 18       0.640750    0.359250         0         1  ...           82.080
# 19       0.602097    0.397903         0         1  ...           76.250
# 20       0.481871    0.518129         0         0  ...           81.620
# 21       0.617631    0.382369         0         1  ...           81.670
# ...           ...         ...       ...       ...  ...              ...
# 12969    0.454932    0.545068         3         4  ...           81.051
# 12970    0.727684    0.272316         7         7  ...           82.192
# 12971    0.673448    0.326552         7         6  ...           80.209
# 12972    0.638845    0.361155         8         5  ...           85.498
# 12973    0.496700    0.503300         7         6  ...           83.959
#
#        A_pacePer40_L10  H_pace_L10  A_pace_L10    H_teamId    A_teamId  \
# 17              78.330      98.500       94.00  1610612741  1610612752
# 18              87.080      98.500      104.50  1610612746  1610612744
# 19              77.500      91.500       93.00  1610612766  1610612739
# 20              76.670      97.945       92.00  1610612753  1610612740
# 21              84.580      98.000      101.50  1610612764  1610612755
# ...                ...         ...         ...         ...         ...
# 12969           83.168      97.259       99.80  1610612757  1610612742
# 12970           80.624      98.631       96.75  1610612738  1610612752
# 12971           85.334      96.250      102.40  1610612756  1610612758
# 12972           86.917     102.598      104.30  1610612749  1610612754
# 12973           82.459     100.750       98.95  1610612747  1610612740
#
#        H_trueShootingPercentage_L10  A_trueShootingPercentage_L10  \
# 17                           0.5100                        0.5730
# 18                           0.5530                        0.6500
# 19                           0.4200                        0.4950
# 20                           0.4900                        0.4780
# 21                           0.5540                        0.6290
# ...                             ...                           ...
# 12969                        0.5395                        0.5587
# 12970                        0.5876                        0.5792
# 12971                        0.6058                        0.5941
# 12972                        0.6296                        0.6305
# 12973                        0.5706                        0.6015
#
#        H_turnoverRatio_L10  A_turnoverRatio_L10
# 17                   19.40                23.40
# 18                   16.30                14.30
# 19                    8.70                15.10
# 20                   18.05                16.30
# 21                   17.30                17.60
# ...                    ...                  ...
# 12969                16.22                10.72
# 12970                15.05                13.69
# 12971                14.64                13.14
# 12972                12.30                11.57
# 12973                14.62                13.51
#
# [12957 rows x 52 columns]

# %%
data_type = {"gameId": str, "teamId": str}
team_stat_flatten = pd.read_csv('../dataset/team_stat_flatten.csv', dtype=data_type )
team_stat_flatten
# Out:
#          gameId         DUEL   GAME_DATE  HOME_WON        H_ELO        A_ELO  \
# 0      21300018  CHI vs. NYK  2013-10-31         1  1516.608800  1582.133300
# 1      21300019  LAC vs. GSW  2013-10-31         1  1575.414200  1574.897700
# 2      21300020  CHA vs. CLE  2013-11-01         1  1349.502100  1377.546500
# 3      21300021  ORL vs. NOP  2013-11-01         1  1309.402000  1422.004600
# 4      21300022  WAS vs. PHI  2013-11-01         0  1452.716800  1469.418000
# ...         ...          ...         ...       ...          ...          ...
# 12952  22301226  POR vs. DAL  2023-12-08         0  1361.139964  1492.541584
# 12953  22301227  BOS vs. NYK  2023-12-08         1  1662.122050  1591.374004
# 12954  22301228  PHX vs. SAC  2023-12-08         0  1551.810711  1526.069995
# 12955  22301229  MIL vs. IND  2023-12-07         0  1601.142185  1502.061541
# 12956  22301230  LAL vs. NOP  2023-12-07         1  1541.467385  1543.760516
#
#        H_ELO_PROB  A_ELO_PROB  H_NB_WIN  A_NB_WIN  ...  H_pacePer40_L10  \
# 0        0.549452    0.450548         0         1  ...           82.080
# 1        0.640750    0.359250         0         1  ...           82.080
# 2        0.602097    0.397903         0         1  ...           76.250
# 3        0.481871    0.518129         0         0  ...           81.620
# 4        0.617631    0.382369         0         1  ...           81.670
# ...           ...         ...       ...       ...  ...              ...
# 12952    0.454932    0.545068         3         4  ...           81.051
# 12953    0.727684    0.272316         7         7  ...           82.192
# 12954    0.673448    0.326552         7         6  ...           80.209
# 12955    0.638845    0.361155         8         5  ...           85.498
# 12956    0.496700    0.503300         7         6  ...           83.959
#
#        A_pacePer40_L10  H_pace_L10  A_pace_L10    H_teamId    A_teamId  \
# 0               78.330      98.500       94.00  1610612741  1610612752
# 1               87.080      98.500      104.50  1610612746  1610612744
# 2               77.500      91.500       93.00  1610612766  1610612739
# 3               76.670      97.945       92.00  1610612753  1610612740
# 4               84.580      98.000      101.50  1610612764  1610612755
# ...                ...         ...         ...         ...         ...
# 12952           83.168      97.259       99.80  1610612757  1610612742
# 12953           80.624      98.631       96.75  1610612738  1610612752
# 12954           85.334      96.250      102.40  1610612756  1610612758
# 12955           86.917     102.598      104.30  1610612749  1610612754
# 12956           82.459     100.750       98.95  1610612747  1610612740
#
#        H_trueShootingPercentage_L10  A_trueShootingPercentage_L10  \
# 0                            0.5100                        0.5730
# 1                            0.5530                        0.6500
# 2                            0.4200                        0.4950
# 3                            0.4900                        0.4780
# 4                            0.5540                        0.6290
# ...                             ...                           ...
# 12952                        0.5395                        0.5587
# 12953                        0.5876                        0.5792
# 12954                        0.6058                        0.5941
# 12955                        0.6296                        0.6305
# 12956                        0.5706                        0.6015
#
#        H_turnoverRatio_L10  A_turnoverRatio_L10
# 0                    19.40                23.40
# 1                    16.30                14.30
# 2                     8.70                15.10
# 3                    18.05                16.30
# 4                    17.30                17.60
# ...                    ...                  ...
# 12952                16.22                10.72
# 12953                15.05                13.69
# 12954                14.64                13.14
# 12955                12.30                11.57
# 12956                14.62                13.51
#
# [12957 rows x 52 columns]

# %%
team_stat_flatten.columns
# Out:
# Index(['gameId', 'DUEL', 'GAME_DATE', 'HOME_WON', 'H_ELO', 'A_ELO',
#        'H_ELO_PROB', 'A_ELO_PROB', 'H_NB_WIN', 'A_NB_WIN', 'H_PCT_3PT_L10',
#        'A_PCT_3PT_L10', 'H_PCT_LANCER_FRANC_L10', 'A_PCT_LANCER_FRANC_L10',
#        'H_PCT_TIR_REUSSI_L10', 'A_PCT_TIR_REUSSI_L10', 'H_PIE_L10',
#        'A_PIE_L10', 'H_assistPercentage_L10', 'A_assistPercentage_L10',
#        'H_assistRatio_L10', 'A_assistRatio_L10', 'H_assistToTurnover_L10',
#        'A_assistToTurnover_L10', 'H_defensiveRating_L10',
#        'A_defensiveRating_L10', 'H_effectiveFieldGoalPercentage_L10',
#        'A_effectiveFieldGoalPercentage_L10', 'H_estimatedDefensiveRating_L10',
#        'A_estimatedDefensiveRating_L10', 'H_estimatedNetRating_L10',
#        'A_estimatedNetRating_L10', 'H_estimatedOffensiveRating_L10',
#        'A_estimatedOffensiveRating_L10', 'H_estimatedPace_L10',
#        'A_estimatedPace_L10', 'H_estimatedTeamTurnoverPercentage_L10',
#        'A_estimatedTeamTurnoverPercentage_L10', 'H_netRating_L10',
#        'A_netRating_L10', 'H_offensiveRating_L10', 'A_offensiveRating_L10',
#        'H_pacePer40_L10', 'A_pacePer40_L10', 'H_pace_L10', 'A_pace_L10',
#        'H_teamId', 'A_teamId', 'H_trueShootingPercentage_L10',
#        'A_trueShootingPercentage_L10', 'H_turnoverRatio_L10',
#        'A_turnoverRatio_L10'],
#       dtype='object')

# %%
team_stat_flatten = team_stat_flatten.drop(columns=['gameId', 'DUEL', 'GAME_DATE','H_teamId', 'A_teamId'])
colonne_a_supprimer = team_stat_flatten.columns[1:]
# Boucle sur chaque paire de colonnes pour calculer la différence
for colonne in colonne_a_supprimer:
    # Extraire le préfixe de la colonne ('H_' ou 'A_')
    prefixe = colonne[0:2]
    # Extraire le nom de la colonne sans le préfixe
    nom_colonne = colonne[2:]
    # Créer une nouvelle colonne pour stocker la différence
    team_stat_flatten[f'{nom_colonne}'] = team_stat_flatten.apply(lambda row: row[f'H_{nom_colonne}'] - row[f'A_{nom_colonne}'], axis=1)

team_stat_flatten = team_stat_flatten.drop(columns=colonne_a_supprimer)
       
team_stat_flatten
# Out:
#        HOME_WON         ELO  ELO_PROB  NB_WIN  PCT_3PT_L10  \
# 0             1  -65.524500  0.098904    -1.0       0.0380
# 1             1    0.516500  0.281499    -1.0      -0.1750
# 2             1  -28.044400  0.204194    -1.0       0.0670
# 3             1 -112.602600 -0.036257     0.0      -0.0330
# 4             0  -16.701200  0.235263    -1.0       0.0190
# ...         ...         ...       ...     ...          ...
# 12952         0 -131.401620 -0.090136    -1.0       0.0281
# 12953         1   70.748046  0.455368     0.0      -0.0308
# 12954         0   25.740716  0.346896     1.0       0.0195
# 12955         0   99.080644  0.277690     3.0       0.0120
# 12956         1   -2.293131 -0.006600     1.0      -0.0301
#
#        PCT_LANCER_FRANC_L10  PCT_TIR_REUSSI_L10  PIE_L10  \
# 0                   -0.0990             -0.0850  -0.1880
# 1                   -0.2180             -0.0410  -0.2060
# 2                   -0.0260             -0.0500  -0.1680
# 3                   -0.2045              0.0285  -0.0035
# 4                   -0.0830             -0.1020  -0.1540
# ...                     ...                 ...      ...
# 12952                0.0784             -0.0198  -0.0425
# 12953               -0.0079              0.0011   0.0096
# 12954                0.0873              0.0058   0.0644
# 12955               -0.0072             -0.0017   0.0392
# 12956               -0.0302             -0.0239  -0.0170
#
#        assistPercentage_L10  assistRatio_L10  ...  estimatedNetRating_L10  \
# 0                    0.1850             2.50  ...                  -24.10
# 1                   -0.0800            -3.60  ...                  -36.80
# 2                   -0.1760            -4.10  ...                  -23.00
# 3                   -0.0405             0.00  ...                   -4.45
# 4                    0.1180            -0.70  ...                  -13.70
# ...                     ...              ...  ...                     ...
# 12952               -0.0380            -2.13  ...                   -6.61
# 12953                0.0262             0.49  ...                    0.35
# 12954               -0.0092            -0.57  ...                    4.31
# 12955               -0.0281            -0.70  ...                    8.28
# 12956                0.0098            -0.57  ...                   -8.47
#
#        estimatedOffensiveRating_L10  estimatedPace_L10  \
# 0                             -1.40              4.060
# 1                            -16.20             -2.460
# 2                            -13.50             -4.580
# 3                             -2.05              6.745
# 4                             -7.20             -3.840
# ...                             ...                ...
# 12952                         -9.34             -1.915
# 12953                         -3.46              1.574
# 12954                          1.14             -4.722
# 12955                          1.09             -3.265
# 12956                        -10.14              1.398
#
#        estimatedTeamTurnoverPercentage_L10  netRating_L10  \
# 0                                  -4.4950         -18.50
# 1                                   1.7360         -40.80
# 2                                  -6.0000         -19.60
# 3                                   1.3120          -2.60
# 4                                  -0.2060         -14.10
# ...                                    ...            ...
# 12952                               5.2200          -6.22
# 12953                               1.4297          -0.36
# 12954                               1.2915           4.54
# 12955                               0.9842           6.22
# 12956                               0.9580          -5.73
#
#        offensiveRating_L10  pacePer40_L10  pace_L10  \
# 0                     1.20          3.750     4.500
# 1                   -13.90         -5.000    -6.000
# 2                   -15.20         -1.250    -1.500
# 3                    -0.60          4.950     5.945
# 4                    -7.70         -2.910    -3.500
# ...                    ...            ...       ...
# 12952                -8.72         -2.117    -2.541
# 12953                -4.31          1.568     1.881
# 12954                 2.96         -5.125    -6.150
# 12955                -1.94         -1.419    -1.702
# 12956                -9.31          1.500     1.800
#
#        trueShootingPercentage_L10  turnoverRatio_L10
# 0                         -0.0630              -4.00
# 1                         -0.0970               2.00
# 2                         -0.0750              -6.40
# 3                          0.0120               1.75
# 4                         -0.0750              -0.30
# ...                           ...                ...
# 12952                     -0.0192               5.50
# 12953                      0.0084               1.36
# 12954                      0.0117               1.50
# 12955                     -0.0009               0.73
# 12956                     -0.0309               1.11
#
# [12957 rows x 24 columns]

# %%
team_stat_flatten.to_csv('../dataset/final_dataset_diff.csv', index=False)
