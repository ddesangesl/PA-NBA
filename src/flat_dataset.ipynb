# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
nb_games = "10"

# %%
data_type = {"gameId": str, "teamId": str}
df_stat_last_perf = pd.read_csv('../dataset/team_stat_last_'+ nb_games +'.csv', dtype=data_type )
df_stat_last_perf
# Out:
#            gameId      teamId   GAME_DATE         DUEL WL  NB_WIN_L10  \
# 0      0021300001  1610612754  2013-10-29  IND vs. ORL  W         0.0
# 1      0021300001  1610612753  2013-10-29    ORL @ IND  L         0.0
# 2      0021300002  1610612748  2013-10-29  MIA vs. CHI  W         0.0
# 3      0021300002  1610612741  2013-10-29    CHI @ MIA  L         0.0
# 4      0021300003  1610612747  2013-10-29  LAL vs. LAC  W         0.0
# ...           ...         ...         ...          ... ..         ...
# 24077  0022301228  1610612758  2023-12-08    SAC @ PHX  W         0.6
# 24078  0022301229  1610612749  2023-12-07  MIL vs. IND  L         0.8
# 24079  0022301229  1610612754  2023-12-07    IND @ MIL  W         0.5
# 24080  0022301230  1610612747  2023-12-07  LAL vs. NOP  W         0.7
# 24081  0022301230  1610612740  2023-12-07    NOP @ LAL  L         0.6
#
#        PCT_TIR_REUSSI_L10  PCT_3PTS_L10  PCT_LANCER_FRANC_L10  \
# 0                     NaN           NaN                   NaN
# 1                     NaN           NaN                   NaN
# 2                     NaN           NaN                   NaN
# 3                     NaN           NaN                   NaN
# 4                     NaN           NaN                   NaN
# ...                   ...           ...                   ...
# 24077              0.4738        0.3759                0.7684
# 24078              0.5201        0.3984                0.7737
# 24079              0.5218        0.3864                0.7809
# 24080              0.4767        0.3244                0.7606
# 24081              0.5006        0.3545                0.7908
#
#        estimatedOffensiveRating_L10  ...  assistToTurnover_L10  \
# 0                               NaN  ...                   NaN
# 1                               NaN  ...                   NaN
# 2                               NaN  ...                   NaN
# 3                               NaN  ...                   NaN
# 4                               NaN  ...                   NaN
# ...                             ...  ...                   ...
# 24077                        114.96  ...                 2.129
# 24078                        122.88  ...                 2.454
# 24079                        121.79  ...                 2.735
# 24080                        108.47  ...                 1.895
# 24081                        118.61  ...                 2.203
#
#        assistRatio_L10  estimatedTeamTurnoverPercentage_L10  \
# 0                  NaN                                  NaN
# 1                  NaN                                  NaN
# 2                  NaN                                  NaN
# 3                  NaN                                  NaN
# 4                  NaN                                  NaN
# ...                ...                                  ...
# 24077            19.61                              12.9317
# 24078            19.75                              12.1841
# 24079            20.45                              11.1999
# 24080            19.35                              14.3494
# 24081            19.92                              13.3914
#
#        turnoverRatio_L10  effectiveFieldGoalPercentage_L10  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
# ...                  ...                               ...
# 24077              13.14                            0.5591
# 24078              12.30                            0.6027
# 24079              11.57                            0.6012
# 24080              14.62                            0.5325
# 24081              13.51                            0.5590
#
#        trueShootingPercentage_L10  estimatedPace_L10  pace_L10  pacePer40_L10  \
# 0                             NaN                NaN       NaN            NaN
# 1                             NaN                NaN       NaN            NaN
# 2                             NaN                NaN       NaN            NaN
# 3                             NaN                NaN       NaN            NaN
# 4                             NaN                NaN       NaN            NaN
# ...                           ...                ...       ...            ...
# 24077                      0.5941            103.950   102.400         85.334
# 24078                      0.6296            104.243   102.598         85.498
# 24079                      0.6305            107.508   104.300         86.917
# 24080                      0.5706            102.164   100.750         83.959
# 24081                      0.6015            100.766    98.950         82.459
#
#        PIE_L10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 24077   0.4814
# 24078   0.5446
# 24079   0.5054
# 24080   0.5255
# 24081   0.5425
#
# [24082 rows x 26 columns]

# %%
df_stat_last_perf['col'] = df_stat_last_perf.groupby('gameId').cumcount() + 1
df_stat_flatten = df_stat_last_perf.pivot_table(index='gameId', columns=df_stat_last_perf.groupby('gameId').cumcount() + 1, values=['teamId', 'GAME_DATE', 'DUEL', 'WL', 'NB_WIN_L'+nb_games,
       'PCT_TIR_REUSSI_L'+nb_games, 'PCT_3PTS_L'+ nb_games, 'PCT_LANCER_FRANC_L'+ nb_games,
       'estimatedOffensiveRating_L'+ nb_games, 'offensiveRating_L'+ nb_games,
       'estimatedDefensiveRating_L'+ nb_games, 'defensiveRating_L'+ nb_games,
       'estimatedNetRating_L'+ nb_games, 'netRating_L'+ nb_games, 'assistPercentage_L'+ nb_games,
       'assistToTurnover_L'+ nb_games, 'assistRatio_L'+ nb_games,
       'estimatedTeamTurnoverPercentage_L'+ nb_games, 'turnoverRatio_L'+ nb_games,
       'effectiveFieldGoalPercentage_L'+ nb_games, 'trueShootingPercentage_L'+ nb_games,
       'estimatedPace_L'+ nb_games, 'pace_L'+ nb_games, 'pacePer40_L'+ nb_games, 'PIE_L'+ nb_games], aggfunc='first')

df_stat_flatten.columns = [f'col{col[1]}' for col in df_stat_flatten.columns]


df_stat_flatten = df_stat_flatten.reset_index()
df_stat_flatten
# Out:
#            gameId         col1       col2        col1        col2  col1  col2  \
# 0      0021300001  IND vs. ORL  ORL @ IND  2013-10-29  2013-10-29   0.0   0.0
# 1      0021300002  MIA vs. CHI  CHI @ MIA  2013-10-29  2013-10-29   0.0   0.0
# 2      0021300003  LAL vs. LAC  LAC @ LAL  2013-10-29  2013-10-29   0.0   0.0
# 3      0021300004  CLE vs. BKN  BKN @ CLE  2013-10-30  2013-10-30   0.0   0.0
# 4      0021300005  PHI vs. MIA  MIA @ PHI  2013-10-30  2013-10-30   0.0   0.1
# ...           ...          ...        ...         ...         ...   ...   ...
# 12036  0022301226  POR vs. DAL  DAL @ POR  2023-12-08  2023-12-08   0.3   0.4
# 12037  0022301227  BOS vs. NYK  NYK @ BOS  2023-12-08  2023-12-08   0.7   0.7
# 12038  0022301228  PHX vs. SAC  SAC @ PHX  2023-12-08  2023-12-08   0.7   0.6
# 12039  0022301229  MIL vs. IND  IND @ MIL  2023-12-07  2023-12-07   0.8   0.5
# 12040  0022301230  LAL vs. NOP  NOP @ LAL  2023-12-07  2023-12-07   0.7   0.6
#
#          col1    col2    col1  ...    col1    col2     col1    col2  \
# 0         NaN     NaN     NaN  ...     NaN     NaN      NaN     NaN
# 1         NaN     NaN     NaN  ...     NaN     NaN      NaN     NaN
# 2         NaN     NaN     NaN  ...     NaN     NaN      NaN     NaN
# 3         NaN     NaN     NaN  ...     NaN     NaN      NaN     NaN
# 4         NaN  0.5500     NaN  ...     NaN  82.080      NaN   98.50
# ...       ...     ...     ...  ...     ...     ...      ...     ...
# 12036  0.3744  0.3463  0.7976  ...  81.051  83.168   97.259   99.80
# 12037  0.3545  0.3853  0.7753  ...  82.192  80.624   98.631   96.75
# 12038  0.3954  0.3759  0.8557  ...  80.209  85.334   96.250  102.40
# 12039  0.3984  0.3864  0.7737  ...  85.498  86.917  102.598  104.30
# 12040  0.3244  0.3545  0.7606  ...  83.959  82.459  100.750   98.95
#
#              col1        col2    col1    col2   col1   col2
# 0      1610612754  1610612753     NaN     NaN    NaN    NaN
# 1      1610612748  1610612741     NaN     NaN    NaN    NaN
# 2      1610612747  1610612746     NaN     NaN    NaN    NaN
# 3      1610612739  1610612751     NaN     NaN    NaN    NaN
# 4      1610612755  1610612748     NaN  0.6310    NaN  20.20
# ...           ...         ...     ...     ...    ...    ...
# 12036  1610612757  1610612742  0.5395  0.5587  16.22  10.72
# 12037  1610612738  1610612752  0.5876  0.5792  15.05  13.69
# 12038  1610612756  1610612758  0.6058  0.5941  14.64  13.14
# 12039  1610612749  1610612754  0.6296  0.6305  12.30  11.57
# 12040  1610612747  1610612740  0.5706  0.6015  14.62  13.51
#
# [12041 rows x 51 columns]

# %%
df_stat_flatten.columns = ['gameId', 'H_DUEL', 'A_DUEL', 'H_GAME_DATE', 'A_GAME_DATE', 'H_NB_WIN_L'+nb_games, 'A_NB_WIN_L'+nb_games, 'H_PCT_3PT_L'+nb_games, 'A_PCT_3PT_L'+nb_games, 'H_PCT_LANCER_FRANC_L'+nb_games, 'A_PCT_LANCER_FRANC_L'+nb_games, 'H_PCT_TIR_REUSSI_L'+nb_games, 'A_PCT_TIR_REUSSI_L'+nb_games, 'H_PIE_L'+nb_games, 'A_PIE_L'+nb_games, 'H_WL', 'A_WL', 'H_assistPercentage_L'+nb_games, 'A_assistPercentage_L'+nb_games, 'H_assistRatio_L'+nb_games, 'A_assistRatio_L'+nb_games, 'H_assistToTurnover_L'+nb_games, 'A_assistToTurnover_L'+nb_games, 'H_defensiveRating_L'+nb_games, 'A_defensiveRating_L'+nb_games, 'H_effectiveFieldGoalPercentage_L'+nb_games, 'A_effectiveFieldGoalPercentage_L'+nb_games, 'H_estimatedDefensiveRating_L'+nb_games, 'A_estimatedDefensiveRating_L'+nb_games, 'H_estimatedNetRating_L'+nb_games, 'A_estimatedNetRating_L'+nb_games, 'H_estimatedOffensiveRating_L'+nb_games, 'A_estimatedOffensiveRating_L'+nb_games, 'H_estimatedPace_L'+nb_games, 'A_estimatedPace_L'+nb_games, 'H_estimatedTeamTurnoverPercentage_L'+nb_games, 'A_estimatedTeamTurnoverPercentage_L'+nb_games, 'H_netRating_L'+nb_games, 'A_netRating_L'+nb_games, 'H_offensiveRating_L'+nb_games, 'A_offensiveRating_L'+nb_games, 'H_pacePer40_L'+nb_games, 'A_pacePer40_L'+nb_games, 'H_pace_L'+nb_games, 'A_pace_L'+nb_games, 'H_teamId', 'A_teamId', 'H_trueShootingPercentage_L'+nb_games, 'A_trueShootingPercentage_L'+nb_games, 'H_turnoverRatio_L'+nb_games, 'A_turnoverRatio_L'+nb_games]
df_stat_flatten
# Out:
#            gameId       H_DUEL     A_DUEL H_GAME_DATE A_GAME_DATE  \
# 0      0021300001  IND vs. ORL  ORL @ IND  2013-10-29  2013-10-29
# 1      0021300002  MIA vs. CHI  CHI @ MIA  2013-10-29  2013-10-29
# 2      0021300003  LAL vs. LAC  LAC @ LAL  2013-10-29  2013-10-29
# 3      0021300004  CLE vs. BKN  BKN @ CLE  2013-10-30  2013-10-30
# 4      0021300005  PHI vs. MIA  MIA @ PHI  2013-10-30  2013-10-30
# ...           ...          ...        ...         ...         ...
# 12036  0022301226  POR vs. DAL  DAL @ POR  2023-12-08  2023-12-08
# 12037  0022301227  BOS vs. NYK  NYK @ BOS  2023-12-08  2023-12-08
# 12038  0022301228  PHX vs. SAC  SAC @ PHX  2023-12-08  2023-12-08
# 12039  0022301229  MIL vs. IND  IND @ MIL  2023-12-07  2023-12-07
# 12040  0022301230  LAL vs. NOP  NOP @ LAL  2023-12-07  2023-12-07
#
#        H_NB_WIN_L10  A_NB_WIN_L10  H_PCT_3PT_L10  A_PCT_3PT_L10  \
# 0               0.0           0.0            NaN            NaN
# 1               0.0           0.0            NaN            NaN
# 2               0.0           0.0            NaN            NaN
# 3               0.0           0.0            NaN            NaN
# 4               0.0           0.1            NaN         0.5500
# ...             ...           ...            ...            ...
# 12036           0.3           0.4         0.3744         0.3463
# 12037           0.7           0.7         0.3545         0.3853
# 12038           0.7           0.6         0.3954         0.3759
# 12039           0.8           0.5         0.3984         0.3864
# 12040           0.7           0.6         0.3244         0.3545
#
#        H_PCT_LANCER_FRANC_L10  ...  H_pacePer40_L10  A_pacePer40_L10  \
# 0                         NaN  ...              NaN              NaN
# 1                         NaN  ...              NaN              NaN
# 2                         NaN  ...              NaN              NaN
# 3                         NaN  ...              NaN              NaN
# 4                         NaN  ...              NaN           82.080
# ...                       ...  ...              ...              ...
# 12036                  0.7976  ...           81.051           83.168
# 12037                  0.7753  ...           82.192           80.624
# 12038                  0.8557  ...           80.209           85.334
# 12039                  0.7737  ...           85.498           86.917
# 12040                  0.7606  ...           83.959           82.459
#
#        H_pace_L10  A_pace_L10    H_teamId    A_teamId  \
# 0             NaN         NaN  1610612754  1610612753
# 1             NaN         NaN  1610612748  1610612741
# 2             NaN         NaN  1610612747  1610612746
# 3             NaN         NaN  1610612739  1610612751
# 4             NaN       98.50  1610612755  1610612748
# ...           ...         ...         ...         ...
# 12036      97.259       99.80  1610612757  1610612742
# 12037      98.631       96.75  1610612738  1610612752
# 12038      96.250      102.40  1610612756  1610612758
# 12039     102.598      104.30  1610612749  1610612754
# 12040     100.750       98.95  1610612747  1610612740
#
#       H_trueShootingPercentage_L10  A_trueShootingPercentage_L10  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                        0.6310
# ...                            ...                           ...
# 12036                       0.5395                        0.5587
# 12037                       0.5876                        0.5792
# 12038                       0.6058                        0.5941
# 12039                       0.6296                        0.6305
# 12040                       0.5706                        0.6015
#
#        H_turnoverRatio_L10  A_turnoverRatio_L10
# 0                      NaN                  NaN
# 1                      NaN                  NaN
# 2                      NaN                  NaN
# 3                      NaN                  NaN
# 4                      NaN                20.20
# ...                    ...                  ...
# 12036                16.22                10.72
# 12037                15.05                13.69
# 12038                14.64                13.14
# 12039                12.30                11.57
# 12040                14.62                13.51
#
# [12041 rows x 51 columns]

# %%
df_stat_flatten = df_stat_flatten.drop('A_DUEL', axis=1)
df_stat_flatten = df_stat_flatten.drop('A_GAME_DATE', axis=1)
df_stat_flatten = df_stat_flatten.drop('A_WL', axis=1)
df_stat_flatten = df_stat_flatten.rename(columns={'H_DUEL': 'DUEL', 'H_GAME_DATE': 'GAME_DATE', 'H_WL': 'HOME_WON'})
df_stat_flatten['HOME_WON'] = df_stat_flatten['HOME_WON'].replace('W', 1)
df_stat_flatten['HOME_WON'] = df_stat_flatten['HOME_WON'].replace('L', 0)
df_stat_flatten
# Out:
#            gameId         DUEL   GAME_DATE  H_NB_WIN_L10  A_NB_WIN_L10  \
# 0      0021300001  IND vs. ORL  2013-10-29           0.0           0.0
# 1      0021300002  MIA vs. CHI  2013-10-29           0.0           0.0
# 2      0021300003  LAL vs. LAC  2013-10-29           0.0           0.0
# 3      0021300004  CLE vs. BKN  2013-10-30           0.0           0.0
# 4      0021300005  PHI vs. MIA  2013-10-30           0.0           0.1
# ...           ...          ...         ...           ...           ...
# 12036  0022301226  POR vs. DAL  2023-12-08           0.3           0.4
# 12037  0022301227  BOS vs. NYK  2023-12-08           0.7           0.7
# 12038  0022301228  PHX vs. SAC  2023-12-08           0.7           0.6
# 12039  0022301229  MIL vs. IND  2023-12-07           0.8           0.5
# 12040  0022301230  LAL vs. NOP  2023-12-07           0.7           0.6
#
#        H_PCT_3PT_L10  A_PCT_3PT_L10  H_PCT_LANCER_FRANC_L10  \
# 0                NaN            NaN                     NaN
# 1                NaN            NaN                     NaN
# 2                NaN            NaN                     NaN
# 3                NaN            NaN                     NaN
# 4                NaN         0.5500                     NaN
# ...              ...            ...                     ...
# 12036         0.3744         0.3463                  0.7976
# 12037         0.3545         0.3853                  0.7753
# 12038         0.3954         0.3759                  0.8557
# 12039         0.3984         0.3864                  0.7737
# 12040         0.3244         0.3545                  0.7606
#
#        A_PCT_LANCER_FRANC_L10  H_PCT_TIR_REUSSI_L10  ...  H_pacePer40_L10  \
# 0                         NaN                   NaN  ...              NaN
# 1                         NaN                   NaN  ...              NaN
# 2                         NaN                   NaN  ...              NaN
# 3                         NaN                   NaN  ...              NaN
# 4                      0.7590                   NaN  ...              NaN
# ...                       ...                   ...  ...              ...
# 12036                  0.7192                0.4321  ...           81.051
# 12037                  0.7832                0.4698  ...           82.192
# 12038                  0.7684                0.4796  ...           80.209
# 12039                  0.7809                0.5201  ...           85.498
# 12040                  0.7908                0.4767  ...           83.959
#
#        A_pacePer40_L10  H_pace_L10  A_pace_L10    H_teamId    A_teamId  \
# 0                  NaN         NaN         NaN  1610612754  1610612753
# 1                  NaN         NaN         NaN  1610612748  1610612741
# 2                  NaN         NaN         NaN  1610612747  1610612746
# 3                  NaN         NaN         NaN  1610612739  1610612751
# 4               82.080         NaN       98.50  1610612755  1610612748
# ...                ...         ...         ...         ...         ...
# 12036           83.168      97.259       99.80  1610612757  1610612742
# 12037           80.624      98.631       96.75  1610612738  1610612752
# 12038           85.334      96.250      102.40  1610612756  1610612758
# 12039           86.917     102.598      104.30  1610612749  1610612754
# 12040           82.459     100.750       98.95  1610612747  1610612740
#
#        H_trueShootingPercentage_L10  A_trueShootingPercentage_L10  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                        0.6310
# ...                             ...                           ...
# 12036                        0.5395                        0.5587
# 12037                        0.5876                        0.5792
# 12038                        0.6058                        0.5941
# 12039                        0.6296                        0.6305
# 12040                        0.5706                        0.6015
#
#        H_turnoverRatio_L10  A_turnoverRatio_L10
# 0                      NaN                  NaN
# 1                      NaN                  NaN
# 2                      NaN                  NaN
# 3                      NaN                  NaN
# 4                      NaN                20.20
# ...                    ...                  ...
# 12036                16.22                10.72
# 12037                15.05                13.69
# 12038                14.64                13.14
# 12039                12.30                11.57
# 12040                14.62                13.51
#
# [12041 rows x 48 columns]

# %%
#df_stat_flatten = df_stat_flatten[['GAME_DATE', 'DUEL']]
df_stat_flatten.to_csv('../dataset/team_stat_flatten.csv', index=False)

# %%
nba_elo = pd.read_csv('../dataset/nba_elo.csv', dtype=data_type )

# %%
nba_elo_copy= nba_elo.copy()
nba_elo_copy
# Out:
#               date  season  neutral playoff team1 team2     elo1_pre  \
# 0       1946-11-01    1947        0     NaN   TRH   NYK  1300.000000
# 1       1946-11-01    1947        0     NaN   NYK   TRH  1300.000000
# 2       1946-11-02    1947        0     NaN   PRO   BOS  1300.000000
# 3       1946-11-02    1947        0     NaN   STB   PIT  1300.000000
# 4       1946-11-02    1947        0     NaN   CHS   NYK  1300.000000
# ...            ...     ...      ...     ...   ...   ...          ...
# 148933  2024-03-30    2024        0     NaN   MEM   ORL  1325.023208
# 148934  2024-03-30    2024        0     NaN   MIL   ATL  1586.179279
# 148935  2024-03-30    2024        0     NaN   NOP   BOS  1635.324867
# 148936  2024-03-30    2024        0     NaN   ORL   MEM  1523.156879
# 148937  2024-03-30    2024        0     NaN   ATL   MIL  1493.120229
#
#            elo2_pre  elo_prob1  elo_prob2    elo1_post    elo2_post  score1  \
# 0       1300.000000   0.640065   0.359935  1293.276700  1306.723300      66
# 1       1300.000000   0.359935   0.640065  1306.723300  1293.276700      68
# 2       1300.000000   0.640065   0.359935  1305.154200  1294.845800      59
# 3       1300.000000   0.640065   0.359935  1304.690800  1295.309200      56
# 4       1306.723300   0.631101   0.368899  1309.652100  1297.071200      63
# ...             ...        ...        ...          ...          ...     ...
# 148933  1523.156879   0.152362   0.847638  1319.643511  1528.536576      88
# 148934  1493.120229   0.490012   0.509988  1596.162979  1483.136529     122
# 148935  1758.207851   0.467116   0.532884  1624.649366  1768.883352      92
# 148936  1325.023208   0.847638   0.152362  1528.536576  1319.643511     118
# 148937  1586.179279   0.509988   0.490012  1483.136529  1596.162979     113
#
#         score2  is_home
# 0           68        1
# 1           66        0
# 2           53        1
# 3           51        1
# 4           47        1
# ...        ...      ...
# 148933     118        0
# 148934     113        0
# 148935     104        1
# 148936      88        1
# 148937     122        1
#
# [148938 rows x 15 columns]

# %%
columns_list = nba_elo_copy.columns.tolist()

print(columns_list)
# Out:
# ['date', 'season', 'neutral', 'playoff', 'team1', 'team2', 'elo1_pre', 'elo2_pre', 'elo_prob1', 'elo_prob2', 'elo1_post', 'elo2_post', 'score1', 'score2', 'is_home']

# %%
columns_to_drop = ['season',  'neutral', 'playoff', 'team2', 'elo1_post', 'elo2_post', 'score1', 'score2', 'is_home']  # Liste des noms des colonnes à supprimer
nba_elo_copy_drop= nba_elo_copy.drop(columns=columns_to_drop)

# %%
nba_elo_copy_drop
# Out:
#               date team1     elo1_pre     elo2_pre  elo_prob1  elo_prob2
# 0       1946-11-01   TRH  1300.000000  1300.000000   0.640065   0.359935
# 1       1946-11-01   NYK  1300.000000  1300.000000   0.359935   0.640065
# 2       1946-11-02   PRO  1300.000000  1300.000000   0.640065   0.359935
# 3       1946-11-02   STB  1300.000000  1300.000000   0.640065   0.359935
# 4       1946-11-02   CHS  1300.000000  1306.723300   0.631101   0.368899
# ...            ...   ...          ...          ...        ...        ...
# 148933  2024-03-30   MEM  1325.023208  1523.156879   0.152362   0.847638
# 148934  2024-03-30   MIL  1586.179279  1493.120229   0.490012   0.509988
# 148935  2024-03-30   NOP  1635.324867  1758.207851   0.467116   0.532884
# 148936  2024-03-30   ORL  1523.156879  1325.023208   0.847638   0.152362
# 148937  2024-03-30   ATL  1493.120229  1586.179279   0.509988   0.490012
#
# [148938 rows x 6 columns]

# %%
nba_elo_copy_drop['team1'] = nba_elo_copy_drop['team1'].replace({'PHO': 'PHX', 'BRK': 'BKN', 'CHO': 'CHA'})

# %%
df_stat_flatten['team1'] = df_stat_flatten['DUEL'].str.split(' vs. ').str[0]

# %%
df_stat_flatten
# Out:
#            gameId         DUEL   GAME_DATE  H_NB_WIN_L10  A_NB_WIN_L10  \
# 0      0021300001  IND vs. ORL  2013-10-29           0.0           0.0
# 1      0021300002  MIA vs. CHI  2013-10-29           0.0           0.0
# 2      0021300003  LAL vs. LAC  2013-10-29           0.0           0.0
# 3      0021300004  CLE vs. BKN  2013-10-30           0.0           0.0
# 4      0021300005  PHI vs. MIA  2013-10-30           0.0           0.1
# ...           ...          ...         ...           ...           ...
# 12036  0022301226  POR vs. DAL  2023-12-08           0.3           0.4
# 12037  0022301227  BOS vs. NYK  2023-12-08           0.7           0.7
# 12038  0022301228  PHX vs. SAC  2023-12-08           0.7           0.6
# 12039  0022301229  MIL vs. IND  2023-12-07           0.8           0.5
# 12040  0022301230  LAL vs. NOP  2023-12-07           0.7           0.6
#
#        H_PCT_3PT_L10  A_PCT_3PT_L10  H_PCT_LANCER_FRANC_L10  \
# 0                NaN            NaN                     NaN
# 1                NaN            NaN                     NaN
# 2                NaN            NaN                     NaN
# 3                NaN            NaN                     NaN
# 4                NaN         0.5500                     NaN
# ...              ...            ...                     ...
# 12036         0.3744         0.3463                  0.7976
# 12037         0.3545         0.3853                  0.7753
# 12038         0.3954         0.3759                  0.8557
# 12039         0.3984         0.3864                  0.7737
# 12040         0.3244         0.3545                  0.7606
#
#        A_PCT_LANCER_FRANC_L10  H_PCT_TIR_REUSSI_L10  ...  A_pacePer40_L10  \
# 0                         NaN                   NaN  ...              NaN
# 1                         NaN                   NaN  ...              NaN
# 2                         NaN                   NaN  ...              NaN
# 3                         NaN                   NaN  ...              NaN
# 4                      0.7590                   NaN  ...           82.080
# ...                       ...                   ...  ...              ...
# 12036                  0.7192                0.4321  ...           83.168
# 12037                  0.7832                0.4698  ...           80.624
# 12038                  0.7684                0.4796  ...           85.334
# 12039                  0.7809                0.5201  ...           86.917
# 12040                  0.7908                0.4767  ...           82.459
#
#        H_pace_L10  A_pace_L10    H_teamId    A_teamId  \
# 0             NaN         NaN  1610612754  1610612753
# 1             NaN         NaN  1610612748  1610612741
# 2             NaN         NaN  1610612747  1610612746
# 3             NaN         NaN  1610612739  1610612751
# 4             NaN       98.50  1610612755  1610612748
# ...           ...         ...         ...         ...
# 12036      97.259       99.80  1610612757  1610612742
# 12037      98.631       96.75  1610612738  1610612752
# 12038      96.250      102.40  1610612756  1610612758
# 12039     102.598      104.30  1610612749  1610612754
# 12040     100.750       98.95  1610612747  1610612740
#
#        H_trueShootingPercentage_L10  A_trueShootingPercentage_L10  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                        0.6310
# ...                             ...                           ...
# 12036                        0.5395                        0.5587
# 12037                        0.5876                        0.5792
# 12038                        0.6058                        0.5941
# 12039                        0.6296                        0.6305
# 12040                        0.5706                        0.6015
#
#        H_turnoverRatio_L10  A_turnoverRatio_L10  team1
# 0                      NaN                  NaN    IND
# 1                      NaN                  NaN    MIA
# 2                      NaN                  NaN    LAL
# 3                      NaN                  NaN    CLE
# 4                      NaN                20.20    PHI
# ...                    ...                  ...    ...
# 12036                16.22                10.72    POR
# 12037                15.05                13.69    BOS
# 12038                14.64                13.14    PHX
# 12039                12.30                11.57    MIL
# 12040                14.62                13.51    LAL
#
# [12041 rows x 49 columns]

# %%
new_column_names = {'date':'GAME_DATE' }
nba_elo_copy_drop_rename= nba_elo_copy_drop.rename(columns=new_column_names)
nba_elo_copy_drop_rename
# Out:
#          GAME_DATE team1     elo1_pre     elo2_pre  elo_prob1  elo_prob2
# 0       1946-11-01   TRH  1300.000000  1300.000000   0.640065   0.359935
# 1       1946-11-01   NYK  1300.000000  1300.000000   0.359935   0.640065
# 2       1946-11-02   PRO  1300.000000  1300.000000   0.640065   0.359935
# 3       1946-11-02   STB  1300.000000  1300.000000   0.640065   0.359935
# 4       1946-11-02   CHS  1300.000000  1306.723300   0.631101   0.368899
# ...            ...   ...          ...          ...        ...        ...
# 148933  2024-03-30   MEM  1325.023208  1523.156879   0.152362   0.847638
# 148934  2024-03-30   MIL  1586.179279  1493.120229   0.490012   0.509988
# 148935  2024-03-30   NOP  1635.324867  1758.207851   0.467116   0.532884
# 148936  2024-03-30   ORL  1523.156879  1325.023208   0.847638   0.152362
# 148937  2024-03-30   ATL  1493.120229  1586.179279   0.509988   0.490012
#
# [148938 rows x 6 columns]

# %%
result = pd.merge(df_stat_flatten, nba_elo_copy_drop_rename, on=['GAME_DATE', 'team1'])

# %%
result
# Out:
#            gameId         DUEL   GAME_DATE  H_NB_WIN_L10  A_NB_WIN_L10  \
# 0      0021300001  IND vs. ORL  2013-10-29           0.0           0.0
# 1      0021300002  MIA vs. CHI  2013-10-29           0.0           0.0
# 2      0021300003  LAL vs. LAC  2013-10-29           0.0           0.0
# 3      0021300004  CLE vs. BKN  2013-10-30           0.0           0.0
# 4      0021300005  PHI vs. MIA  2013-10-30           0.0           0.1
# ...           ...          ...         ...           ...           ...
# 11911  0022301226  POR vs. DAL  2023-12-08           0.3           0.4
# 11912  0022301227  BOS vs. NYK  2023-12-08           0.7           0.7
# 11913  0022301228  PHX vs. SAC  2023-12-08           0.7           0.6
# 11914  0022301229  MIL vs. IND  2023-12-07           0.8           0.5
# 11915  0022301230  LAL vs. NOP  2023-12-07           0.7           0.6
#
#        H_PCT_3PT_L10  A_PCT_3PT_L10  H_PCT_LANCER_FRANC_L10  \
# 0                NaN            NaN                     NaN
# 1                NaN            NaN                     NaN
# 2                NaN            NaN                     NaN
# 3                NaN            NaN                     NaN
# 4                NaN         0.5500                     NaN
# ...              ...            ...                     ...
# 11911         0.3744         0.3463                  0.7976
# 11912         0.3545         0.3853                  0.7753
# 11913         0.3954         0.3759                  0.8557
# 11914         0.3984         0.3864                  0.7737
# 11915         0.3244         0.3545                  0.7606
#
#        A_PCT_LANCER_FRANC_L10  H_PCT_TIR_REUSSI_L10  ...    A_teamId  \
# 0                         NaN                   NaN  ...  1610612753
# 1                         NaN                   NaN  ...  1610612741
# 2                         NaN                   NaN  ...  1610612746
# 3                         NaN                   NaN  ...  1610612751
# 4                      0.7590                   NaN  ...  1610612748
# ...                       ...                   ...  ...         ...
# 11911                  0.7192                0.4321  ...  1610612742
# 11912                  0.7832                0.4698  ...  1610612752
# 11913                  0.7684                0.4796  ...  1610612758
# 11914                  0.7809                0.5201  ...  1610612754
# 11915                  0.7908                0.4767  ...  1610612740
#
#        H_trueShootingPercentage_L10  A_trueShootingPercentage_L10  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                        0.6310
# ...                             ...                           ...
# 11911                        0.5395                        0.5587
# 11912                        0.5876                        0.5792
# 11913                        0.6058                        0.5941
# 11914                        0.6296                        0.6305
# 11915                        0.5706                        0.6015
#
#        H_turnoverRatio_L10  A_turnoverRatio_L10  team1     elo1_pre  \
# 0                      NaN                  NaN    IND  1583.572100
# 1                      NaN                  NaN    MIA  1691.889600
# 2                      NaN                  NaN    LAL  1511.020000
# 3                      NaN                  NaN    CLE  1369.282300
# 4                      NaN                20.20    PHI  1459.690400
# ...                    ...                  ...    ...          ...
# 11911                16.22                10.72    POR  1361.139964
# 11912                15.05                13.69    BOS  1662.122050
# 11913                14.64                13.14    PHX  1551.810711
# 11914                12.30                11.57    MIL  1601.142185
# 11915                14.62                13.51    LAL  1541.467385
#
#           elo2_pre  elo_prob1  elo_prob2
# 0      1313.231700   0.893961   0.106039
# 1      1519.912400   0.827159   0.172841
# 2      1586.588400   0.535102   0.464898
# 3      1548.436500   0.388019   0.611981
# 4      1695.193200   0.314316   0.685684
# ...            ...        ...        ...
# 11911  1492.541584   0.454932   0.545068
# 11912  1591.374004   0.727684   0.272316
# 11913  1526.069995   0.673448   0.326552
# 11914  1502.061541   0.638845   0.361155
# 11915  1543.760516   0.496700   0.503300
#
# [11916 rows x 53 columns]

# %%
new_column_names = {'elo1_pre':'H_ELO' , 'elo2_pre': 'A_ELO', 'elo_prob1':'H_ELO_PROB', 'elo_prob2':'A_ELO_PROB'}
result= result.rename(columns=new_column_names)
result
# Out:
#            gameId         DUEL   GAME_DATE  H_NB_WIN_L10  A_NB_WIN_L10  \
# 0      0021300001  IND vs. ORL  2013-10-29           0.0           0.0
# 1      0021300002  MIA vs. CHI  2013-10-29           0.0           0.0
# 2      0021300003  LAL vs. LAC  2013-10-29           0.0           0.0
# 3      0021300004  CLE vs. BKN  2013-10-30           0.0           0.0
# 4      0021300005  PHI vs. MIA  2013-10-30           0.0           0.1
# ...           ...          ...         ...           ...           ...
# 11911  0022301226  POR vs. DAL  2023-12-08           0.3           0.4
# 11912  0022301227  BOS vs. NYK  2023-12-08           0.7           0.7
# 11913  0022301228  PHX vs. SAC  2023-12-08           0.7           0.6
# 11914  0022301229  MIL vs. IND  2023-12-07           0.8           0.5
# 11915  0022301230  LAL vs. NOP  2023-12-07           0.7           0.6
#
#        H_PCT_3PT_L10  A_PCT_3PT_L10  H_PCT_LANCER_FRANC_L10  \
# 0                NaN            NaN                     NaN
# 1                NaN            NaN                     NaN
# 2                NaN            NaN                     NaN
# 3                NaN            NaN                     NaN
# 4                NaN         0.5500                     NaN
# ...              ...            ...                     ...
# 11911         0.3744         0.3463                  0.7976
# 11912         0.3545         0.3853                  0.7753
# 11913         0.3954         0.3759                  0.8557
# 11914         0.3984         0.3864                  0.7737
# 11915         0.3244         0.3545                  0.7606
#
#        A_PCT_LANCER_FRANC_L10  H_PCT_TIR_REUSSI_L10  ...    A_teamId  \
# 0                         NaN                   NaN  ...  1610612753
# 1                         NaN                   NaN  ...  1610612741
# 2                         NaN                   NaN  ...  1610612746
# 3                         NaN                   NaN  ...  1610612751
# 4                      0.7590                   NaN  ...  1610612748
# ...                       ...                   ...  ...         ...
# 11911                  0.7192                0.4321  ...  1610612742
# 11912                  0.7832                0.4698  ...  1610612752
# 11913                  0.7684                0.4796  ...  1610612758
# 11914                  0.7809                0.5201  ...  1610612754
# 11915                  0.7908                0.4767  ...  1610612740
#
#        H_trueShootingPercentage_L10  A_trueShootingPercentage_L10  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                        0.6310
# ...                             ...                           ...
# 11911                        0.5395                        0.5587
# 11912                        0.5876                        0.5792
# 11913                        0.6058                        0.5941
# 11914                        0.6296                        0.6305
# 11915                        0.5706                        0.6015
#
#        H_turnoverRatio_L10  A_turnoverRatio_L10  team1        H_ELO  \
# 0                      NaN                  NaN    IND  1583.572100
# 1                      NaN                  NaN    MIA  1691.889600
# 2                      NaN                  NaN    LAL  1511.020000
# 3                      NaN                  NaN    CLE  1369.282300
# 4                      NaN                20.20    PHI  1459.690400
# ...                    ...                  ...    ...          ...
# 11911                16.22                10.72    POR  1361.139964
# 11912                15.05                13.69    BOS  1662.122050
# 11913                14.64                13.14    PHX  1551.810711
# 11914                12.30                11.57    MIL  1601.142185
# 11915                14.62                13.51    LAL  1541.467385
#
#              A_ELO  H_ELO_PROB  A_ELO_PROB
# 0      1313.231700    0.893961    0.106039
# 1      1519.912400    0.827159    0.172841
# 2      1586.588400    0.535102    0.464898
# 3      1548.436500    0.388019    0.611981
# 4      1695.193200    0.314316    0.685684
# ...            ...         ...         ...
# 11911  1492.541584    0.454932    0.545068
# 11912  1591.374004    0.727684    0.272316
# 11913  1526.069995    0.673448    0.326552
# 11914  1502.061541    0.638845    0.361155
# 11915  1543.760516    0.496700    0.503300
#
# [11916 rows x 53 columns]

# %%
new_order = ['gameId', 'DUEL','GAME_DATE','HOME_WON','H_ELO','A_ELO','H_ELO_PROB','A_ELO_PROB','H_NB_WIN_L'+nb_games,'A_NB_WIN_L'+nb_games, 'H_PCT_3PT_L'+ nb_games,
       'A_PCT_3PT_L'+ nb_games, 'H_PCT_LANCER_FRANC_L'+ nb_games, 'A_PCT_LANCER_FRANC_L'+ nb_games,
       'H_PCT_TIR_REUSSI_L'+ nb_games, 'A_PCT_TIR_REUSSI_L'+ nb_games, 'H_PIE_L'+ nb_games,
       'A_PIE_L'+ nb_games,  'H_assistPercentage_L'+ nb_games,
       'A_assistPercentage_L'+ nb_games, 'H_assistRatio_L'+ nb_games, 'A_assistRatio_L'+ nb_games,
       'H_assistToTurnover_L'+ nb_games, 'A_assistToTurnover_L'+ nb_games,
       'H_defensiveRating_L'+ nb_games, 'A_defensiveRating_L'+ nb_games,
       'H_effectiveFieldGoalPercentage_L'+ nb_games,
       'A_effectiveFieldGoalPercentage_L'+ nb_games, 'H_estimatedDefensiveRating_L'+ nb_games,
       'A_estimatedDefensiveRating_L'+ nb_games, 'H_estimatedNetRating_L'+ nb_games,
       'A_estimatedNetRating_L'+ nb_games, 'H_estimatedOffensiveRating_L'+ nb_games,
       'A_estimatedOffensiveRating_L'+ nb_games, 'H_estimatedPace_L'+ nb_games,
       'A_estimatedPace_L'+ nb_games, 'H_estimatedTeamTurnoverPercentage_L'+ nb_games,
       'A_estimatedTeamTurnoverPercentage_L'+ nb_games, 'H_netRating_L'+ nb_games,
       'A_netRating_L'+ nb_games, 'H_offensiveRating_L'+ nb_games, 'A_offensiveRating_L'+ nb_games,
       'H_pacePer40_L'+ nb_games, 'A_pacePer40_L'+ nb_games, 'H_pace_L'+ nb_games, 'A_pace_L'+ nb_games,
       'H_teamId', 'A_teamId', 'H_trueShootingPercentage_L'+ nb_games,
       'A_trueShootingPercentage_L'+ nb_games, 'H_turnoverRatio_L'+ nb_games,
       'A_turnoverRatio_L'+ nb_games, 'team1']

# Réorganiser les colonnes
result = result.reindex(columns=new_order)

# %%
result = result.drop(columns=['team1'])
result
# Out:
#            gameId         DUEL   GAME_DATE  HOME_WON        H_ELO  \
# 0      0021300001  IND vs. ORL  2013-10-29         1  1583.572100
# 1      0021300002  MIA vs. CHI  2013-10-29         1  1691.889600
# 2      0021300003  LAL vs. LAC  2013-10-29         1  1511.020000
# 3      0021300004  CLE vs. BKN  2013-10-30         1  1369.282300
# 4      0021300005  PHI vs. MIA  2013-10-30         1  1459.690400
# ...           ...          ...         ...       ...          ...
# 11911  0022301226  POR vs. DAL  2023-12-08         0  1361.139964
# 11912  0022301227  BOS vs. NYK  2023-12-08         1  1662.122050
# 11913  0022301228  PHX vs. SAC  2023-12-08         0  1551.810711
# 11914  0022301229  MIL vs. IND  2023-12-07         0  1601.142185
# 11915  0022301230  LAL vs. NOP  2023-12-07         1  1541.467385
#
#              A_ELO  H_ELO_PROB  A_ELO_PROB  H_NB_WIN_L10  A_NB_WIN_L10  ...  \
# 0      1313.231700    0.893961    0.106039           0.0           0.0  ...
# 1      1519.912400    0.827159    0.172841           0.0           0.0  ...
# 2      1586.588400    0.535102    0.464898           0.0           0.0  ...
# 3      1548.436500    0.388019    0.611981           0.0           0.0  ...
# 4      1695.193200    0.314316    0.685684           0.0           0.1  ...
# ...            ...         ...         ...           ...           ...  ...
# 11911  1492.541584    0.454932    0.545068           0.3           0.4  ...
# 11912  1591.374004    0.727684    0.272316           0.7           0.7  ...
# 11913  1526.069995    0.673448    0.326552           0.7           0.6  ...
# 11914  1502.061541    0.638845    0.361155           0.8           0.5  ...
# 11915  1543.760516    0.496700    0.503300           0.7           0.6  ...
#
#        H_pacePer40_L10  A_pacePer40_L10  H_pace_L10  A_pace_L10    H_teamId  \
# 0                  NaN              NaN         NaN         NaN  1610612754
# 1                  NaN              NaN         NaN         NaN  1610612748
# 2                  NaN              NaN         NaN         NaN  1610612747
# 3                  NaN              NaN         NaN         NaN  1610612739
# 4                  NaN           82.080         NaN       98.50  1610612755
# ...                ...              ...         ...         ...         ...
# 11911           81.051           83.168      97.259       99.80  1610612757
# 11912           82.192           80.624      98.631       96.75  1610612738
# 11913           80.209           85.334      96.250      102.40  1610612756
# 11914           85.498           86.917     102.598      104.30  1610612749
# 11915           83.959           82.459     100.750       98.95  1610612747
#
#          A_teamId  H_trueShootingPercentage_L10  A_trueShootingPercentage_L10  \
# 0      1610612753                           NaN                           NaN
# 1      1610612741                           NaN                           NaN
# 2      1610612746                           NaN                           NaN
# 3      1610612751                           NaN                           NaN
# 4      1610612748                           NaN                        0.6310
# ...           ...                           ...                           ...
# 11911  1610612742                        0.5395                        0.5587
# 11912  1610612752                        0.5876                        0.5792
# 11913  1610612758                        0.6058                        0.5941
# 11914  1610612754                        0.6296                        0.6305
# 11915  1610612740                        0.5706                        0.6015
#
#        H_turnoverRatio_L10  A_turnoverRatio_L10
# 0                      NaN                  NaN
# 1                      NaN                  NaN
# 2                      NaN                  NaN
# 3                      NaN                  NaN
# 4                      NaN                20.20
# ...                    ...                  ...
# 11911                16.22                10.72
# 11912                15.05                13.69
# 11913                14.64                13.14
# 11914                12.30                11.57
# 11915                14.62                13.51
#
# [11916 rows x 52 columns]

# %%
result.to_csv('../dataset/team_stat_flatten.csv', index=False)
result = result.dropna()

# %%
result.to_csv('../dataset/team_stat_flatten.csv', index=False)
result
# Out:
#            gameId         DUEL   GAME_DATE  HOME_WON        H_ELO  \
# 17     0021300018  CHI vs. NYK  2013-10-31         1  1516.608800
# 18     0021300019  LAC vs. GSW  2013-10-31         1  1575.414200
# 19     0021300020  CHA vs. CLE  2013-11-01         1  1349.502100
# 20     0021300021  ORL vs. NOP  2013-11-01         1  1309.402000
# 21     0021300022  WAS vs. PHI  2013-11-01         0  1452.716800
# ...           ...          ...         ...       ...          ...
# 11911  0022301226  POR vs. DAL  2023-12-08         0  1361.139964
# 11912  0022301227  BOS vs. NYK  2023-12-08         1  1662.122050
# 11913  0022301228  PHX vs. SAC  2023-12-08         0  1551.810711
# 11914  0022301229  MIL vs. IND  2023-12-07         0  1601.142185
# 11915  0022301230  LAL vs. NOP  2023-12-07         1  1541.467385
#
#              A_ELO  H_ELO_PROB  A_ELO_PROB  H_NB_WIN_L10  A_NB_WIN_L10  ...  \
# 17     1582.133300    0.549452    0.450548           0.0           0.1  ...
# 18     1574.897700    0.640750    0.359250           0.0           0.1  ...
# 19     1377.546500    0.602097    0.397903           0.0           0.1  ...
# 20     1422.004600    0.481871    0.518129           0.0           0.0  ...
# 21     1469.418000    0.617631    0.382369           0.0           0.1  ...
# ...            ...         ...         ...           ...           ...  ...
# 11911  1492.541584    0.454932    0.545068           0.3           0.4  ...
# 11912  1591.374004    0.727684    0.272316           0.7           0.7  ...
# 11913  1526.069995    0.673448    0.326552           0.7           0.6  ...
# 11914  1502.061541    0.638845    0.361155           0.8           0.5  ...
# 11915  1543.760516    0.496700    0.503300           0.7           0.6  ...
#
#        H_pacePer40_L10  A_pacePer40_L10  H_pace_L10  A_pace_L10    H_teamId  \
# 17              82.080           78.330      98.500       94.00  1610612741
# 18              82.080           87.080      98.500      104.50  1610612746
# 19              76.250           77.500      91.500       93.00  1610612766
# 20              81.620           76.670      97.945       92.00  1610612753
# 21              81.670           84.580      98.000      101.50  1610612764
# ...                ...              ...         ...         ...         ...
# 11911           81.051           83.168      97.259       99.80  1610612757
# 11912           82.192           80.624      98.631       96.75  1610612738
# 11913           80.209           85.334      96.250      102.40  1610612756
# 11914           85.498           86.917     102.598      104.30  1610612749
# 11915           83.959           82.459     100.750       98.95  1610612747
#
#          A_teamId  H_trueShootingPercentage_L10  A_trueShootingPercentage_L10  \
# 17     1610612752                        0.5100                        0.5730
# 18     1610612744                        0.5530                        0.6500
# 19     1610612739                        0.4200                        0.4950
# 20     1610612740                        0.4900                        0.4780
# 21     1610612755                        0.5540                        0.6290
# ...           ...                           ...                           ...
# 11911  1610612742                        0.5395                        0.5587
# 11912  1610612752                        0.5876                        0.5792
# 11913  1610612758                        0.6058                        0.5941
# 11914  1610612754                        0.6296                        0.6305
# 11915  1610612740                        0.5706                        0.6015
#
#        H_turnoverRatio_L10  A_turnoverRatio_L10
# 17                   19.40                23.40
# 18                   16.30                14.30
# 19                    8.70                15.10
# 20                   18.05                16.30
# 21                   17.30                17.60
# ...                    ...                  ...
# 11911                16.22                10.72
# 11912                15.05                13.69
# 11913                14.64                13.14
# 11914                12.30                11.57
# 11915                14.62                13.51
#
# [11899 rows x 52 columns]

# %%
data_type = {"gameId": str, "teamId": str}
team_stat_flatten = pd.read_csv('../dataset/team_stat_flatten.csv', dtype=data_type )
team_stat_flatten
# Out:
#            gameId         DUEL   GAME_DATE  HOME_WON        H_ELO  \
# 0      0021300018  CHI vs. NYK  2013-10-31         1  1516.608800
# 1      0021300019  LAC vs. GSW  2013-10-31         1  1575.414200
# 2      0021300020  CHA vs. CLE  2013-11-01         1  1349.502100
# 3      0021300021  ORL vs. NOP  2013-11-01         1  1309.402000
# 4      0021300022  WAS vs. PHI  2013-11-01         0  1452.716800
# ...           ...          ...         ...       ...          ...
# 11894  0022301226  POR vs. DAL  2023-12-08         0  1361.139964
# 11895  0022301227  BOS vs. NYK  2023-12-08         1  1662.122050
# 11896  0022301228  PHX vs. SAC  2023-12-08         0  1551.810711
# 11897  0022301229  MIL vs. IND  2023-12-07         0  1601.142185
# 11898  0022301230  LAL vs. NOP  2023-12-07         1  1541.467385
#
#              A_ELO  H_ELO_PROB  A_ELO_PROB  H_NB_WIN_L10  A_NB_WIN_L10  ...  \
# 0      1582.133300    0.549452    0.450548           0.0           0.1  ...
# 1      1574.897700    0.640750    0.359250           0.0           0.1  ...
# 2      1377.546500    0.602097    0.397903           0.0           0.1  ...
# 3      1422.004600    0.481871    0.518129           0.0           0.0  ...
# 4      1469.418000    0.617631    0.382369           0.0           0.1  ...
# ...            ...         ...         ...           ...           ...  ...
# 11894  1492.541584    0.454932    0.545068           0.3           0.4  ...
# 11895  1591.374004    0.727684    0.272316           0.7           0.7  ...
# 11896  1526.069995    0.673448    0.326552           0.7           0.6  ...
# 11897  1502.061541    0.638845    0.361155           0.8           0.5  ...
# 11898  1543.760516    0.496700    0.503300           0.7           0.6  ...
#
#        H_pacePer40_L10  A_pacePer40_L10  H_pace_L10  A_pace_L10    H_teamId  \
# 0               82.080           78.330      98.500       94.00  1610612741
# 1               82.080           87.080      98.500      104.50  1610612746
# 2               76.250           77.500      91.500       93.00  1610612766
# 3               81.620           76.670      97.945       92.00  1610612753
# 4               81.670           84.580      98.000      101.50  1610612764
# ...                ...              ...         ...         ...         ...
# 11894           81.051           83.168      97.259       99.80  1610612757
# 11895           82.192           80.624      98.631       96.75  1610612738
# 11896           80.209           85.334      96.250      102.40  1610612756
# 11897           85.498           86.917     102.598      104.30  1610612749
# 11898           83.959           82.459     100.750       98.95  1610612747
#
#          A_teamId  H_trueShootingPercentage_L10  A_trueShootingPercentage_L10  \
# 0      1610612752                        0.5100                        0.5730
# 1      1610612744                        0.5530                        0.6500
# 2      1610612739                        0.4200                        0.4950
# 3      1610612740                        0.4900                        0.4780
# 4      1610612755                        0.5540                        0.6290
# ...           ...                           ...                           ...
# 11894  1610612742                        0.5395                        0.5587
# 11895  1610612752                        0.5876                        0.5792
# 11896  1610612758                        0.6058                        0.5941
# 11897  1610612754                        0.6296                        0.6305
# 11898  1610612740                        0.5706                        0.6015
#
#        H_turnoverRatio_L10  A_turnoverRatio_L10
# 0                    19.40                23.40
# 1                    16.30                14.30
# 2                     8.70                15.10
# 3                    18.05                16.30
# 4                    17.30                17.60
# ...                    ...                  ...
# 11894                16.22                10.72
# 11895                15.05                13.69
# 11896                14.64                13.14
# 11897                12.30                11.57
# 11898                14.62                13.51
#
# [11899 rows x 52 columns]

# %%
team_stat_flatten.columns
# Out:
# Index(['gameId', 'DUEL', 'GAME_DATE', 'HOME_WON', 'H_ELO', 'A_ELO',
#        'H_ELO_PROB', 'A_ELO_PROB', 'H_NB_WIN_L10', 'A_NB_WIN_L10',
#        'H_PCT_3PT_L10', 'A_PCT_3PT_L10', 'H_PCT_LANCER_FRANC_L10',
#        'A_PCT_LANCER_FRANC_L10', 'H_PCT_TIR_REUSSI_L10',
#        'A_PCT_TIR_REUSSI_L10', 'H_PIE_L10', 'A_PIE_L10',
#        'H_assistPercentage_L10', 'A_assistPercentage_L10', 'H_assistRatio_L10',
#        'A_assistRatio_L10', 'H_assistToTurnover_L10', 'A_assistToTurnover_L10',
#        'H_defensiveRating_L10', 'A_defensiveRating_L10',
#        'H_effectiveFieldGoalPercentage_L10',
#        'A_effectiveFieldGoalPercentage_L10', 'H_estimatedDefensiveRating_L10',
#        'A_estimatedDefensiveRating_L10', 'H_estimatedNetRating_L10',
#        'A_estimatedNetRating_L10', 'H_estimatedOffensiveRating_L10',
#        'A_estimatedOffensiveRating_L10', 'H_estimatedPace_L10',
#        'A_estimatedPace_L10', 'H_estimatedTeamTurnoverPercentage_L10',
#        'A_estimatedTeamTurnoverPercentage_L10', 'H_netRating_L10',
#        'A_netRating_L10', 'H_offensiveRating_L10', 'A_offensiveRating_L10',
#        'H_pacePer40_L10', 'A_pacePer40_L10', 'H_pace_L10', 'A_pace_L10',
#        'H_teamId', 'A_teamId', 'H_trueShootingPercentage_L10',
#        'A_trueShootingPercentage_L10', 'H_turnoverRatio_L10',
#        'A_turnoverRatio_L10'],
#       dtype='object')

# %%
team_stat_flatten = team_stat_flatten.drop(columns=['DUEL'])
colonne_a_supprimer = team_stat_flatten.columns[3:].tolist()
# Boucle sur chaque paire de colonnes pour calculer la différence
i = 0 
for colonne in colonne_a_supprimer:
    
    
    if colonne != "H_teamId" and colonne != "A_teamId":
           # Extraire le préfixe de la colonne ('H_' ou 'A_')
           prefixe = colonne[0:2]
           # Extraire le nom de la colonne sans le préfixe
           nom_colonne = colonne[2:]
           # Créer une nouvelle colonne pour stocker la différence
           team_stat_flatten[f'{nom_colonne}'] = team_stat_flatten.apply(lambda row: row[f'H_{nom_colonne}'] - row[f'A_{nom_colonne}'], axis=1)
    i = i +1    
colonne_a_supprimer.remove("A_teamId")
colonne_a_supprimer.remove("H_teamId")
team_stat_flatten = team_stat_flatten.drop(columns=colonne_a_supprimer)
       
team_stat_flatten
# Out:
#            gameId   GAME_DATE  HOME_WON    H_teamId    A_teamId         ELO  \
# 0      0021300018  2013-10-31         1  1610612741  1610612752  -65.524500
# 1      0021300019  2013-10-31         1  1610612746  1610612744    0.516500
# 2      0021300020  2013-11-01         1  1610612766  1610612739  -28.044400
# 3      0021300021  2013-11-01         1  1610612753  1610612740 -112.602600
# 4      0021300022  2013-11-01         0  1610612764  1610612755  -16.701200
# ...           ...         ...       ...         ...         ...         ...
# 11894  0022301226  2023-12-08         0  1610612757  1610612742 -131.401620
# 11895  0022301227  2023-12-08         1  1610612738  1610612752   70.748046
# 11896  0022301228  2023-12-08         0  1610612756  1610612758   25.740716
# 11897  0022301229  2023-12-07         0  1610612749  1610612754   99.080644
# 11898  0022301230  2023-12-07         1  1610612747  1610612740   -2.293131
#
#        ELO_PROB  NB_WIN_L10  PCT_3PT_L10  PCT_LANCER_FRANC_L10  ...  \
# 0      0.098904        -0.1       0.0380               -0.0990  ...
# 1      0.281499        -0.1      -0.1750               -0.2180  ...
# 2      0.204194        -0.1       0.0670               -0.0260  ...
# 3     -0.036257         0.0      -0.0330               -0.2045  ...
# 4      0.235263        -0.1       0.0190               -0.0830  ...
# ...         ...         ...          ...                   ...  ...
# 11894 -0.090136        -0.1       0.0281                0.0784  ...
# 11895  0.455368         0.0      -0.0308               -0.0079  ...
# 11896  0.346896         0.1       0.0195                0.0873  ...
# 11897  0.277690         0.3       0.0120               -0.0072  ...
# 11898 -0.006600         0.1      -0.0301               -0.0302  ...
#
#        estimatedNetRating_L10  estimatedOffensiveRating_L10  \
# 0                      -24.10                         -1.40
# 1                      -36.80                        -16.20
# 2                      -23.00                        -13.50
# 3                       -4.45                         -2.05
# 4                      -13.70                         -7.20
# ...                       ...                           ...
# 11894                   -6.61                         -9.34
# 11895                    0.35                         -3.46
# 11896                    4.31                          1.14
# 11897                    8.28                          1.09
# 11898                   -8.47                        -10.14
#
#        estimatedPace_L10  estimatedTeamTurnoverPercentage_L10  netRating_L10  \
# 0                  4.060                              -4.4950         -18.50
# 1                 -2.460                               1.7360         -40.80
# 2                 -4.580                              -6.0000         -19.60
# 3                  6.745                               1.3120          -2.60
# 4                 -3.840                              -0.2060         -14.10
# ...                  ...                                  ...            ...
# 11894             -1.915                               5.2200          -6.22
# 11895              1.574                               1.4297          -0.36
# 11896             -4.722                               1.2915           4.54
# 11897             -3.265                               0.9842           6.22
# 11898              1.398                               0.9580          -5.73
#
#        offensiveRating_L10  pacePer40_L10  pace_L10  \
# 0                     1.20          3.750     4.500
# 1                   -13.90         -5.000    -6.000
# 2                   -15.20         -1.250    -1.500
# 3                    -0.60          4.950     5.945
# 4                    -7.70         -2.910    -3.500
# ...                    ...            ...       ...
# 11894                -8.72         -2.117    -2.541
# 11895                -4.31          1.568     1.881
# 11896                 2.96         -5.125    -6.150
# 11897                -1.94         -1.419    -1.702
# 11898                -9.31          1.500     1.800
#
#        trueShootingPercentage_L10  turnoverRatio_L10
# 0                         -0.0630              -4.00
# 1                         -0.0970               2.00
# 2                         -0.0750              -6.40
# 3                          0.0120               1.75
# 4                         -0.0750              -0.30
# ...                           ...                ...
# 11894                     -0.0192               5.50
# 11895                      0.0084               1.36
# 11896                      0.0117               1.50
# 11897                     -0.0009               0.73
# 11898                     -0.0309               1.11
#
# [11899 rows x 28 columns]

# %%
team_stat_flatten.to_csv('../dataset/final_dataset_diff_f_L'+ nb_games +'.csv', index=False)
