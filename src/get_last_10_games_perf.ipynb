# %%
import pandas as pd

# %%
data_type = {"gameId": str, "teamId": str}
df_stat = pd.read_csv('../dataset/merged_team_stats.csv', dtype=data_type )
df_stat
# Out:
#          gameId      teamId   GAME_DATE         DUEL WL  NB_VICTOIRE  \
# 0      21300002  1610612741  2013-10-29    CHI @ MIA  L            0
# 1      21300001  1610612754  2013-10-29  IND vs. ORL  W            1
# 2      21300002  1610612748  2013-10-29  MIA vs. CHI  W            1
# 3      21300003  1610612747  2013-10-29  LAL vs. LAC  W            1
# 4      21300001  1610612753  2013-10-29    ORL @ IND  L            0
# ...         ...         ...         ...          ... ..          ...
# 25943  22300961  1610612756  2024-03-15    PHX @ CHA  W           39
# 25944  22300962  1610612748  2024-03-15    MIA @ DET  W           36
# 25945  22300963  1610612761  2024-03-15  TOR vs. ORL  L           23
# 25946  22300965  1610612743  2024-03-15    DEN @ SAS  W           47
# 25947  22300964  1610612740  2024-03-15  NOP vs. LAC  W           40
#
#        NB_DEFAITE  PCT_VICTOIRE  DUREE_MATCH  TIR REUSSI  ...  turnoverRatio  \
# ...

# %%
df_chicago = df_stat[df_stat['teamId'] == "1610612741"]
df_chicago.reset_index(drop=True, inplace=True)
df_chicago
# Out:
#        gameId      teamId   GAME_DATE         DUEL WL  NB_VICTOIRE  \
# 0    21300002  1610612741  2013-10-29    CHI @ MIA  L            0
# 1    21300018  1610612741  2013-10-31  CHI vs. NYK  W            1
# 2    21300034  1610612741  2013-11-02    CHI @ PHI  L            1
# 3    21300061  1610612741  2013-11-06    CHI @ IND  L            1
# 4    21300079  1610612741  2013-11-08  CHI vs. UTA  W            2
# ..        ...         ...         ...          ... ..          ...
# 855  22300907  1610612741  2024-03-07    CHI @ GSW  W           31
# 856  22300917  1610612741  2024-03-09    CHI @ LAC  L           31
# 857  22300935  1610612741  2024-03-11  CHI vs. DAL  L           31
# 858  22300948  1610612741  2024-03-13    CHI @ IND  W           32
# 859  22300956  1610612741  2024-03-14  CHI vs. LAC  L           32
#
#      NB_DEFAITE  PCT_VICTOIRE  DUREE_MATCH  TIR REUSSI  ...  turnoverRatio  \
# 0             1         0.000          240          35  ...           19.4
# ...

# %%
index = 11
df_last_10_games = df_chicago.iloc[max(0, index - 10):index]
df_last_10_games
# Out:
#       gameId      teamId   GAME_DATE         DUEL WL  NB_VICTOIRE  NB_DEFAITE  \
# 1   21300018  1610612741  2013-10-31  CHI vs. NYK  W            1           1
# 2   21300034  1610612741  2013-11-02    CHI @ PHI  L            1           2
# 3   21300061  1610612741  2013-11-06    CHI @ IND  L            1           3
# 4   21300079  1610612741  2013-11-08  CHI vs. UTA  W            2           3
# 5   21300102  1610612741  2013-11-11  CHI vs. CLE  W            3           3
# 6   21300126  1610612741  2013-11-15    CHI @ TOR  W            4           3
# 7   21300140  1610612741  2013-11-16  CHI vs. IND  W            5           3
# 8   21300151  1610612741  2013-11-18  CHI vs. CHA  W            6           3
# 9   21300175  1610612741  2013-11-21    CHI @ DEN  L            6           4
# 10  21300185  1610612741  2013-11-22    CHI @ POR  L            6           5
#
#     PCT_VICTOIRE  DUREE_MATCH  TIR REUSSI  ...  turnoverRatio  \
# ...

# %%
game_id = df_last_10_games['gameId'][10]
print(game_id)
# Out:
# 21300185

# %%
nb_wins = (df_last_10_games['WL'] == 'W').sum()
print(nb_wins)
pct_tir = df_last_10_games['PCT_TIR_REUSSI'].mean()
print(pct_tir)
pct_3pt = df_last_10_games['PCT_3PTS'].mean()
print(pct_3pt)
pct_lf = df_last_10_games['PCT_LANCER_FRANC'].mean()
print(pct_lf)
e_offensive_rating = df_last_10_games['estimatedOffensiveRating'].mean()
print(e_offensive_rating)
offensive_rating = df_last_10_games['offensiveRating'].mean()
print(offensive_rating)
e_defensive_rating = df_last_10_games['estimatedDefensiveRating'].mean()
print(e_defensive_rating)
defensive_rating = df_last_10_games['defensiveRating'].mean()
print(defensive_rating)
e_net_rating = df_last_10_games['estimatedNetRating'].mean()
print(e_net_rating)
net_rating = df_last_10_games['netRating'].mean()
print(net_rating)
ast_pct = df_last_10_games['assistPercentage'].mean()
print(ast_pct)
ast_to_tov = df_last_10_games['assistToTurnover'].mean()
print(ast_to_tov)
ast_ratio = df_last_10_games['assistRatio'].mean()
print(ast_ratio)
e_tov_ratio = df_last_10_games['estimatedTeamTurnoverPercentage'].mean()
print(e_tov_ratio)
tov_ratio = df_last_10_games['turnoverRatio'].mean()
print(tov_ratio)
effective_field_goal_percentage = df_last_10_games['effectiveFieldGoalPercentage'].mean()
print(effective_field_goal_percentage)
true_shooting_percentage = df_last_10_games['trueShootingPercentage'].mean()
print(true_shooting_percentage)
e_pace = df_last_10_games['estimatedPace'].mean()
print(e_pace)
pace = df_last_10_games['pace'].mean()
print(pace)
pace_per_40 = df_last_10_games['pacePer40'].mean()
print(pace_per_40)
pie = df_last_10_games['PIE'].mean()
print(pie)
# Out:
# 6
# 0.4244
# 0.3534
# 0.8279
# 98.25999999999999
# 101.02
# 92.86999999999999
# 96.04
# 5.360000000000001
# 4.96
# 0.604
# 1.274
# 16.060000000000002
# 17.8112
# 18.28
# 0.4558
# 0.5118
# 95.298
# 92.45
# 77.04199999999999
# 0.5501

# %%
df_chicago
# Out:
#        gameId      teamId   GAME_DATE         DUEL WL  NB_VICTOIRE  \
# 0    21300002  1610612741  2013-10-29    CHI @ MIA  L            0
# 1    21300018  1610612741  2013-10-31  CHI vs. NYK  W            1
# 2    21300034  1610612741  2013-11-02    CHI @ PHI  L            1
# 3    21300061  1610612741  2013-11-06    CHI @ IND  L            1
# 4    21300079  1610612741  2013-11-08  CHI vs. UTA  W            2
# ..        ...         ...         ...          ... ..          ...
# 855  22300907  1610612741  2024-03-07    CHI @ GSW  W           31
# 856  22300917  1610612741  2024-03-09    CHI @ LAC  L           31
# 857  22300935  1610612741  2024-03-11  CHI vs. DAL  L           31
# 858  22300948  1610612741  2024-03-13    CHI @ IND  W           32
# 859  22300956  1610612741  2024-03-14  CHI vs. LAC  L           32
#
#      NB_DEFAITE  PCT_VICTOIRE  DUREE_MATCH  TIR REUSSI  ...  turnoverRatio  \
# 0             1         0.000          240          35  ...           19.4
# ...

# %%
df_stat_last_10_perf = pd.DataFrame(columns=['gameId', 'teamId', 'GAME_DATE', 'DUEL','WL','NB_WIN', 'PCT_TIR_REUSSI_L10','PCT_3PTS_L10', 
                           'PCT_LANCER_FRANC_L10','estimatedOffensiveRating_L10', 'offensiveRating_L10',
                           'estimatedDefensiveRating_L10',
                           'defensiveRating_L10','estimatedNetRating_L10', 'netRating_L10', 'assistPercentage_L10',
                           'assistToTurnover_L10', 'assistRatio_L10','estimatedTeamTurnoverPercentage_L10', 'turnoverRatio_L10',
                           'effectiveFieldGoalPercentage_L10','trueShootingPercentage_L10', 'estimatedPace_L10', 'pace_L10',
                           'pacePer40_L10', 'PIE_L10'])

for team in list(set(df_stat['teamId'].tolist())):
    team_stats = df_stat[df_stat['teamId'] == team]
    team_stats.reset_index(drop=True, inplace=True)
    index = 0
    while index < len(team_stats):
        df_last_10_games = team_stats.iloc[max(0, index - 10):index]
        df_last_10_games.reset_index(drop=True, inplace=True)
        new_row = {"gameId" :  team_stats['gameId'][index],
                   "teamId" : team_stats['teamId'][index],
                   "GAME_DATE" : team_stats['GAME_DATE'][index],
                   "DUEL" : team_stats['DUEL'][index],
                   "WL" : team_stats['WL'][index],
                   "NB_WIN" : (df_last_10_games['WL'] == 'W').sum(),
                   "PCT_TIR_REUSSI_L10" : df_last_10_games['PCT_TIR_REUSSI'].mean(),
                   "PCT_3PTS_L10" : df_last_10_games['PCT_3PTS'].mean(),
                   "PCT_LANCER_FRANC_L10" : df_last_10_games['PCT_LANCER_FRANC'].mean(),
                   "estimatedOffensiveRating_L10" : df_last_10_games['estimatedOffensiveRating'].mean(),
                   "offensiveRating_L10" : df_last_10_games['offensiveRating'].mean(),
                   "estimatedDefensiveRating_L10" : df_last_10_games['estimatedDefensiveRating'].mean(),
                   "defensiveRating_L10" : df_last_10_games['defensiveRating'].mean(),
                   "estimatedNetRating_L10" : df_last_10_games['estimatedNetRating'].mean(),
                   "netRating_L10" : df_last_10_games['netRating'].mean(),
                   "assistPercentage_L10" : df_last_10_games['assistPercentage'].mean(),
                   "assistToTurnover_L10" : df_last_10_games['assistToTurnover'].mean(),
                   "assistRatio_L10" : df_last_10_games['assistRatio'].mean(),
                   "estimatedTeamTurnoverPercentage_L10" : df_last_10_games['estimatedTeamTurnoverPercentage'].mean(),
                   "turnoverRatio_L10" : df_last_10_games['turnoverRatio'].mean(),
                   "effectiveFieldGoalPercentage_L10" : df_last_10_games['effectiveFieldGoalPercentage'].mean(),
                   "trueShootingPercentage_L10" : df_last_10_games['trueShootingPercentage'].mean(),
                   "estimatedPace_L10" : df_last_10_games['estimatedPace'].mean(),
                   "pace_L10" : df_last_10_games['pace'].mean(),
                   "pacePer40_L10" : df_last_10_games['pacePer40'].mean(),
                   "PIE_L10" : df_last_10_games['PIE'].mean()}
        df_stat_last_10_perf.loc[len(df_stat_last_10_perf)] = new_row
        index += 1
df_stat_last_10_perf
# Out:
#          gameId      teamId   GAME_DATE         DUEL WL  NB_WIN  \
# 0      21300006  1610612761  2013-10-30  TOR vs. BOS  W       0
# 1      21300023  1610612761  2013-11-01    TOR @ ATL  L       1
# 2      21300037  1610612761  2013-11-02    TOR @ MIL  W       1
# 3      21300051  1610612761  2013-11-05  TOR vs. MIA  L       2
# 4      21300060  1610612761  2013-11-06    TOR @ CHA  L       2
# ...         ...         ...         ...          ... ..     ...
# 25943  22300895  1610612739  2024-03-06    CLE @ ATL  L       5
# 25944  22300911  1610612739  2024-03-08  CLE vs. MIN  W       5
# 25945  22300930  1610612739  2024-03-10  CLE vs. BKN  L       5
# 25946  22300934  1610612739  2024-03-11  CLE vs. PHX  L       5
# 25947  22300951  1610612739  2024-03-13    CLE @ NOP  W       5
#
#        PCT_TIR_REUSSI_L10  PCT_3PTS_L10  PCT_LANCER_FRANC_L10  \
# 0                     NaN           NaN                   NaN
# 1                0.442000      0.294000                0.5220
# ...

# %%
df_stat_last_10_perf.to_csv('../dataset/team_stat_last_10.csv', index=False)

# %%
df_stat_last_10_perf = df_stat_last_10_perf.sort_values(by='gameId')
df_stat_last_10_perf.reset_index(drop=True, inplace=True)
df_stat_last_10_perf
# Out:
#          gameId      teamId   GAME_DATE         DUEL WL  NB_WIN  \
# 0      21300001  1610612754  2013-10-29  IND vs. ORL  W       0
# 1      21300001  1610612753  2013-10-29    ORL @ IND  L       0
# 2      21300002  1610612748  2013-10-29  MIA vs. CHI  W       0
# 3      21300002  1610612741  2013-10-29    CHI @ MIA  L       0
# 4      21300003  1610612746  2013-10-29    LAC @ LAL  L       0
# ...         ...         ...         ...          ... ..     ...
# 25943  22301228  1610612758  2023-12-08    SAC @ PHX  W       6
# 25944  22301229  1610612749  2023-12-07  MIL vs. IND  L       8
# 25945  22301229  1610612754  2023-12-07    IND @ MIL  W       5
# 25946  22301230  1610612747  2023-12-07  LAL vs. NOP  W       7
# 25947  22301230  1610612740  2023-12-07    NOP @ LAL  L       6
#
#        PCT_TIR_REUSSI_L10  PCT_3PTS_L10  PCT_LANCER_FRANC_L10  \
# 0                     NaN           NaN                   NaN
# 1                     NaN           NaN                   NaN
# ...

# %%
df_stat_last_10_perf.to_csv('../dataset/team_stat_last_10.csv', index=False)

# %%
a = df_stat_last_10_perf[df_stat_last_10_perf['gameId'] == '21300018']
a
# Out:
#       gameId      teamId   GAME_DATE         DUEL WL  NB_WIN  \
# 34  21300018  1610612741  2013-10-31  CHI vs. NYK  W       0
# 35  21300018  1610612752  2013-10-31    NYK @ CHI  L       1
#
#     PCT_TIR_REUSSI_L10  PCT_3PTS_L10  PCT_LANCER_FRANC_L10  \
# 34               0.422         0.269                 0.783
# 35               0.507         0.231                 0.882
#
#     estimatedOffensiveRating_L10  ...  assistToTurnover_L10  assistRatio_L10  \
# 34                          93.9  ...                  1.21             17.0
# 35                          95.3  ...                  0.77             14.5
#
#     estimatedTeamTurnoverPercentage_L10  turnoverRatio_L10  \
# 34                               18.790               19.4
# 35                               23.285               23.4
#
#     effectiveFieldGoalPercentage_L10  trueShootingPercentage_L10  \
# 34                             0.464                       0.510
# ...

# %%
a.reset_index(inplace=True)
a
# Out:
#    index    gameId      teamId   GAME_DATE         DUEL WL  NB_WIN  \
# 0     34  21300018  1610612741  2013-10-31  CHI vs. NYK  W       0
# 1     35  21300018  1610612752  2013-10-31    NYK @ CHI  L       1
#
#    PCT_TIR_REUSSI_L10  PCT_3PTS_L10  PCT_LANCER_FRANC_L10  ...  \
# 0               0.422         0.269                 0.783  ...
# 1               0.507         0.231                 0.882  ...
#
#    assistToTurnover_L10  assistRatio_L10  estimatedTeamTurnoverPercentage_L10  \
# 0                  1.21             17.0                               18.790
# 1                  0.77             14.5                               23.285
#
#    turnoverRatio_L10  effectiveFieldGoalPercentage_L10  \
# 0               19.4                             0.464
# 1               23.4                             0.528
#
#    trueShootingPercentage_L10  estimatedPace_L10  pace_L10  pacePer40_L10  \
# 0                       0.510             100.44      98.5          82.08
# ...

# %%
"""print('vs' in a['DUEL'].values[0])
print()
df_stat_last_10_perf.loc[a['index'].values[0]] = a.loc[1]
df_stat_last_10_perf.loc[a['index'].values[1]] = a.loc[0]
df_stat_last_10_perf"""
# Out:
# "print('vs' in a['DUEL'].values[0])\nprint()\ndf_stat_last_10_perf.loc[a['index'].values[0]] = a.loc[1]\ndf_stat_last_10_perf.loc[a['index'].values[1]] = a.loc[0]\ndf_stat_last_10_perf"

# %%
for game_id in list(set(df_stat_last_10_perf['gameId'].tolist())):
    df_game = df_stat_last_10_perf[df_stat_last_10_perf['gameId'] == game_id]
    df_game.reset_index(inplace=True)
    if '@' in df_game['DUEL'].values[0]:
        df_stat_last_10_perf.loc[df_game['index'].values[0]] = df_game.loc[1]
        df_stat_last_10_perf.loc[df_game['index'].values[1]] = df_game.loc[0]
        
df_stat_last_10_perf
# Out:
#          gameId      teamId   GAME_DATE         DUEL WL  NB_WIN  \
# 0      21300001  1610612754  2013-10-29  IND vs. ORL  W       0
# 1      21300001  1610612753  2013-10-29    ORL @ IND  L       0
# 2      21300002  1610612748  2013-10-29  MIA vs. CHI  W       0
# 3      21300002  1610612741  2013-10-29    CHI @ MIA  L       0
# 4      21300003  1610612747  2013-10-29  LAL vs. LAC  W       0
# ...         ...         ...         ...          ... ..     ...
# 25943  22301228  1610612758  2023-12-08    SAC @ PHX  W       6
# 25944  22301229  1610612749  2023-12-07  MIL vs. IND  L       8
# 25945  22301229  1610612754  2023-12-07    IND @ MIL  W       5
# 25946  22301230  1610612747  2023-12-07  LAL vs. NOP  W       7
# 25947  22301230  1610612740  2023-12-07    NOP @ LAL  L       6
#
#        PCT_TIR_REUSSI_L10  PCT_3PTS_L10  PCT_LANCER_FRANC_L10  \
# 0                     NaN           NaN                   NaN
# 1                     NaN           NaN                   NaN
# ...

# %%
df_stat_last_10_perf.to_csv('../dataset/team_stat_last_10.csv', index=False)
print(df_stat_last_10_perf.columns)
# Out:
# Index(['gameId', 'teamId', 'GAME_DATE', 'DUEL', 'WL', 'NB_WIN',
#        'PCT_TIR_REUSSI_L10', 'PCT_3PTS_L10', 'PCT_LANCER_FRANC_L10',
#        'estimatedOffensiveRating_L10', 'offensiveRating_L10',
#        'estimatedDefensiveRating_L10', 'defensiveRating_L10',
#        'estimatedNetRating_L10', 'netRating_L10', 'assistPercentage_L10',
#        'assistToTurnover_L10', 'assistRatio_L10',
#        'estimatedTeamTurnoverPercentage_L10', 'turnoverRatio_L10',
#        'effectiveFieldGoalPercentage_L10', 'trueShootingPercentage_L10',
#        'estimatedPace_L10', 'pace_L10', 'pacePer40_L10', 'PIE_L10'],
#       dtype='object')

# %%
df_stat_last_10_perf['col'] = df_stat_last_10_perf.groupby('gameId').cumcount() + 1
df_stat_last_10_perf = df_stat_last_10_perf.pivot_table(index='gameId', columns=df_stat_last_10_perf.groupby('gameId').cumcount() + 1, values=['teamId', 'GAME_DATE', 'DUEL', 'WL', 'NB_WIN',
       'PCT_TIR_REUSSI_L10', 'PCT_3PTS_L10', 'PCT_LANCER_FRANC_L10',
       'estimatedOffensiveRating_L10', 'offensiveRating_L10',
       'estimatedDefensiveRating_L10', 'defensiveRating_L10',
       'estimatedNetRating_L10', 'netRating_L10', 'assistPercentage_L10',
       'assistToTurnover_L10', 'assistRatio_L10',
       'estimatedTeamTurnoverPercentage_L10', 'turnoverRatio_L10',
       'effectiveFieldGoalPercentage_L10', 'trueShootingPercentage_L10',
       'estimatedPace_L10', 'pace_L10', 'pacePer40_L10', 'PIE_L10'], aggfunc='first')
df_stat_last_10_perf.columns = [f'col{col[1]}' for col in df_stat_last_10_perf.columns]

df_stat_last_10_perf
df_applati = df_stat_last_10_perf.reset_index()
df_applati
# Out:
#          gameId         col1       col2        col1        col2  col1  col2  \
# 0      21300001  IND vs. ORL  ORL @ IND  2013-10-29  2013-10-29     0     0
# 1      21300002  MIA vs. CHI  CHI @ MIA  2013-10-29  2013-10-29     0     0
# 2      21300003  LAL vs. LAC  LAC @ LAL  2013-10-29  2013-10-29     0     0
# 3      21300004  CLE vs. BKN  BKN @ CLE  2013-10-30  2013-10-30     0     0
# 4      21300005  PHI vs. MIA  MIA @ PHI  2013-10-30  2013-10-30     0     1
# ...         ...          ...        ...         ...         ...   ...   ...
# 12969  22301226  POR vs. DAL  DAL @ POR  2023-12-08  2023-12-08     3     4
# 12970  22301227  BOS vs. NYK  NYK @ BOS  2023-12-08  2023-12-08     7     7
# 12971  22301228  PHX vs. SAC  SAC @ PHX  2023-12-08  2023-12-08     7     6
# 12972  22301229  MIL vs. IND  IND @ MIL  2023-12-07  2023-12-07     8     5
# 12973  22301230  LAL vs. NOP  NOP @ LAL  2023-12-07  2023-12-07     7     6
#
# ...

# %%
print(['GAME_DATE', 'DUEL', 'WL', 'NB_WIN','PCT_TIR_REUSSI_L10', 'PCT_3PTS_L10', 'PCT_LANCER_FRANC_L10','estimatedOffensiveRating_L10', 'offensiveRating_L10','estimatedDefensiveRating_L10', 'defensiveRating_L10','estimatedNetRating_L10', 'netRating_L10', 'assistPercentage_L10','assistToTurnover_L10', 'assistRatio_L10','estimatedTeamTurnoverPercentage_L10', 'turnoverRatio_L10','effectiveFieldGoalPercentage_L10', 'trueShootingPercentage_L10','estimatedPace_L10', 'pace_L10', 'pacePer40_L10'])
liste_nom_colonnes = df_applati.columns
liste_nom_colonnes
# Out:
# ['GAME_DATE', 'DUEL', 'WL', 'NB_WIN', 'PCT_TIR_REUSSI_L10', 'PCT_3PTS_L10', 'PCT_LANCER_FRANC_L10', 'estimatedOffensiveRating_L10', 'offensiveRating_L10', 'estimatedDefensiveRating_L10', 'defensiveRating_L10', 'estimatedNetRating_L10', 'netRating_L10', 'assistPercentage_L10', 'assistToTurnover_L10', 'assistRatio_L10', 'estimatedTeamTurnoverPercentage_L10', 'turnoverRatio_L10', 'effectiveFieldGoalPercentage_L10', 'trueShootingPercentage_L10', 'estimatedPace_L10', 'pace_L10', 'pacePer40_L10']
# Index(['gameId', 'col1', 'col2', 'col1', 'col2', 'col1', 'col2', 'col1',
#        'col2', 'col1', 'col2', 'col1', 'col2', 'col1', 'col2', 'col1', 'col2',
#        'col1', 'col2', 'col1', 'col2', 'col1', 'col2', 'col1', 'col2', 'col1',
#        'col2', 'col1', 'col2', 'col1', 'col2', 'col1', 'col2', 'col1', 'col2',
#        'col1', 'col2', 'col1', 'col2', 'col1', 'col2', 'col1', 'col2', 'col1',
#        'col2', 'col1', 'col2', 'col1', 'col2', 'col1', 'col2'],
#       dtype='object')

# %%
print(len(df_applati.columns))
df_applati.columns = ['game_id','H_TEAM_ID', 'A_TEAM_ID', 'H_GAME_DATE', 'A_GAME_DATE', 'H_DUEL', 'A_DUEL', 'H_WL', 'A_WL', 'H_NB_WIN', 'A_NB_WIN', 'H_PCT_TIR_REUSSI_L10', 'A_PCT_TIR_REUSSI_L10', 'H_PCT_3PTS_L10', 'A_PCT_3PTS_L10', 'H_PCT_LANCER_FRANC_L10', 'A_PCT_LANCER_FRANC_L10', 'H_estimatedOffensiveRating_L10', 'A_estimatedOffensiveRating_L10', 'H_offensiveRating_L10', 'A_offensiveRating_L10', 'H_estimatedDefensiveRating_L10', 'A_estimatedDefensiveRating_L10', 'H_defensiveRating_L10', 'A_defensiveRating_L10', 'H_estimatedNetRating_L10', 'A_estimatedNetRating_L10', 'H_netRating_L10', 'A_netRating_L10', 'H_assistPercentage_L10', 'A_assistPercentage_L10', 'H_assistToTurnover_L10', 'A_assistToTurnover_L10', 'H_assistRatio_L10', 'A_assistRatio_L10', 'H_estimatedTeamTurnoverPercentage_L10', 'A_estimatedTeamTurnoverPercentage_L10', 'H_turnoverRatio_L10', 'A_turnoverRatio_L10', 'H_effectiveFieldGoalPercentage_L10', 'A_effectiveFieldGoalPercentage_L10', 'H_trueShootingPercentage_L10', 'A_trueShootingPercentage_L10', 'H_estimatedPace_L10', 'A_estimatedPace_L10', 'H_pace_L10', 'A_pace_L10', 'H_pacePer40_L10', 'A_pacePer40_L10', 'H_PIE_L10', 'A_PIE_L10']

df_applati
# Out:
# 51
#         game_id    H_TEAM_ID  A_TEAM_ID H_GAME_DATE A_GAME_DATE  H_DUEL  \
# 0      21300001  IND vs. ORL  ORL @ IND  2013-10-29  2013-10-29       0
# 1      21300002  MIA vs. CHI  CHI @ MIA  2013-10-29  2013-10-29       0
# 2      21300003  LAL vs. LAC  LAC @ LAL  2013-10-29  2013-10-29       0
# 3      21300004  CLE vs. BKN  BKN @ CLE  2013-10-30  2013-10-30       0
# 4      21300005  PHI vs. MIA  MIA @ PHI  2013-10-30  2013-10-30       0
# ...         ...          ...        ...         ...         ...     ...
# 12969  22301226  POR vs. DAL  DAL @ POR  2023-12-08  2023-12-08       3
# 12970  22301227  BOS vs. NYK  NYK @ BOS  2023-12-08  2023-12-08       7
# 12971  22301228  PHX vs. SAC  SAC @ PHX  2023-12-08  2023-12-08       7
# 12972  22301229  MIL vs. IND  IND @ MIL  2023-12-07  2023-12-07       8
# 12973  22301230  LAL vs. NOP  NOP @ LAL  2023-12-07  2023-12-07       7
#
#        A_DUEL    H_WL    A_WL  H_NB_WIN  ...  H_trueShootingPercentage_L10  \
# ...
